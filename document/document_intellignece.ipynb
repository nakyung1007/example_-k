# %% [markdown]
# ## 환경 설정

# %%
# %pip install azure-ai-formrecognizer
# Out:
# Collecting azure-ai-formrecognizer
#   Using cached azure_ai_formrecognizer-3.3.3-py3-none-any.whl.metadata (64 kB)
# Collecting azure-core>=1.23.0 (from azure-ai-formrecognizer)
#   Using cached azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Collecting msrest>=0.6.21 (from azure-ai-formrecognizer)
#   Using cached msrest-0.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting azure-common>=1.1 (from azure-ai-formrecognizer)
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from azure-ai-formrecognizer) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (2024.2.2)
# Collecting isodate>=0.6.0 (from msrest>=0.6.21->azure-ai-formrecognizer)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.6.21->azure-ai-formrecognizer)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-formrecognizer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-formrecognizer) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-formrecognizer) (2.2.1)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Using cached azure_ai_formrecognizer-3.3.3-py3-none-any.whl (301 kB)
# Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Using cached azure_core-1.32.0-py3-none-any.whl (198 kB)
# Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: azure-common, oauthlib, isodate, requests-oauthlib, azure-core, msrest, azure-ai-formrecognizer
# Successfully installed azure-ai-formrecognizer-3.3.3 azure-common-1.1.28 azure-core-1.32.0 isodate-0.7.2 msrest-0.7.1 oauthlib-3.2.2 requests-oauthlib-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 읽기 모델 코드
# https://learn.microsoft.com/ko-kr/azure/ai-services/document-intelligence/how-to-guides/use-sdk-rest-api?view=doc-intel-3.1.0&preserve-view=tru&tabs=macOS&pivots=programming-language-rest-api

# %%
"""
This code sample shows Prebuilt Read operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://learn.microsoft.com/azure/applied-ai-services/form-recognizer/quickstarts/get-started-v3-sdk-rest-api?view=doc-intel-3.1.0&pivots=programming-language-python
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
endpoint = "https://b040-document.cognitiveservices.azure.com/"
key = "9njyuOpUp5Z5pFEZmGom6Yt8lMSP4FnVSKeHm981aJnUUCfFC5VPJQQJ99ALAC4f1cMXJ3w3AAALACOGqCyV"

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

def analyze_read():
    # sample document
    #formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"
    formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/rest-api/read.png"
    
    document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    poller = document_analysis_client.begin_analyze_document_from_url(
            "prebuilt-read", formUrl)
    result = poller.result()

    print ("Document contains content: ", result.content)
    
    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")


if __name__ == "__main__":
    analyze_read()
# Out:
# Document contains content:  While healthcare is still in the early stages of its Al journey, we are seeing pharmaceutical and other life sciences organizations making major investments in Al and related technologies." TOM LAWRY | National Director for Al, Health and Life Sciences | Microsoft
# As pharmaceutical and other life sciences organizations invest in and deploy advanced technologies, they are beginning to see benefits in diverse areas across their organizations. Companies are looking to incorporate automation and continuing smart factory investments to reduce costs in drug discovery, research and development, and manufacturing and supply chain management. Many life sciences organizations are also choosing to stay with more virtual approaches in the "new normal" - particularly in clinical trials and sales and marketing areas.
# Enhancing the patient and provider experience
# Clinical trial sponsors are continually seeking to make clinical trials faster and to improve the experience for patients and physicians. The COVID-19 pandemic has accelerated the adoption of decentralized clinical trials, with an increase in trial activities conducted remotely and in participants' homes. In a Mckinsey survey1 up to 98 percent of patients reported satisfaction with telemedicine. In the same report, 72 percent of physicians surveyed reported similar or better experiences with remote engagement compared with in-person visits.
# The shift of trial activities closer to patients has been enabled by a myriad of evolving technologies and services (e.g., electronic consent, telehealth and remote patient monitoring). The aim to use technology to improve the patient experience and convenience has also broadened trial access to reach a broader, more diverse patient population.
# "It's an interesting and exciting time right now," said Keren Priyadarshini, Regional Business Lead - Asia, Worldwide Health, Microsoft. "It used to be that physicians were key. Now, suddenly, patients are feeling empowered by technology. Pharmaceutical companies and other life sciences companies are realizing they have to pay attention to the patient experience in addition to the physician experience."
# Enhanced patient experiences can be delivered in many different ways. One example of a life sciences product that leverages the intelligent cloud to directly affect the patient experience is the Tandem® Diabetes Care insulin pump. The Tandem® t:slim X2 insulin pump with Basal-IQ technology enables patients with Type 1 diabetes to predict and prevent the low levels of blood sugar that cause hypoglycemia.2 The algorithm-driven, software- updatable pump improves the patient experience by automating chronic disease management and eliminating the need for constant finger pricks to check glucose levels.
# Tandem was able to create and deploy this innovation by leveraging the Al and machine learning capabilities of the intelligent cloud. As Al and other technologies continue to advance, potential use cases will multiply. "Speed to value is going to continue to accelerate," said Lawry.
# In addition to enhancing the patient experience, pharmaceutical and other life sciences companies can leverage advanced technologies to improve relationships with providers. For example, COVID-19 is driving changes in the way companies interact with clinicians. Prior to COVID-19, 75 percent of physicians preferred in-person sales visits from medtech reps; likewise, 77 percent of physicians preferred in- person sales visits from pharma reps.3
# Since the advent of COVID-19, however, physician preferences are moving toward virtual visits. Only 53 percent of physicians now express a preference for in-person visits from medtech reps and only 40 percent prefer in-person visits from pharma reps." That puts the onus on pharmaceutical and life sciences organizations to deliver valuable and engaging virtual visits to providers.
# One way to do that is to leverage text analytics capabilities to enhance the provider information stored in the organization's customer relationship management (CRM) system. For example, a rep setting up a visit with 'Dr. X' could run text analytics on publicly available resources on the web to identify on which specific topics Dr. X has been writing about and commenting. "All kinds of publicly available information can
# " All kinds of publicly
# available information can be mined with text analytics technology, which can be used to arm the sales rep with relevant information even before he or she meets the doctor. It's a totally different, digital game now."
# KEREN PRIYADARSHINI | Regional Business Lead - Asia, Worldwide Health | Microsoft
# EMBRACING DIGITAL TRANSFORMATION IN LIFE SCIENCES ORGANIZATIONS
# 2
# ----Analyzing Read from page #1----
# Page has width: 915.0 and height: 1190.0, measured with unit: pixel
# ...Line # 0 has text content 'While healthcare is still in the early stages of its Al journey, we' within bounding box '[258.0, 54.0], [818.0, 55.0], [818.0, 79.0], [258.0, 77.0]'
# ...Line # 1 has text content 'are seeing pharmaceutical and other life sciences organizations' within bounding box '[258.0, 83.0], [826.0, 83.0], [826.0, 106.0], [258.0, 106.0]'
# ...Line # 2 has text content 'making major investments in Al and related technologies."' within bounding box '[259.0, 112.0], [783.0, 112.0], [783.0, 134.0], [259.0, 135.0]'
# ...Line # 3 has text content 'TOM LAWRY | National Director for Al, Health and Life Sciences | Microsoft' within bounding box '[257.0, 151.0], [637.0, 151.0], [637.0, 167.0], [257.0, 167.0]'
# ...Line # 4 has text content 'As pharmaceutical and other life sciences organizations invest' within bounding box '[74.0, 240.0], [423.0, 240.0], [423.0, 258.0], [74.0, 257.0]'
# ...Line # 5 has text content 'in and deploy advanced technologies, they are beginning to see' within bounding box '[76.0, 259.0], [434.0, 259.0], [434.0, 277.0], [76.0, 277.0]'
# ...Line # 6 has text content 'benefits in diverse areas across their organizations. Companies' within bounding box '[76.0, 277.0], [428.0, 277.0], [428.0, 295.0], [76.0, 294.0]'
# ...Line # 7 has text content 'are looking to incorporate automation and continuing smart' within bounding box '[76.0, 296.0], [413.0, 296.0], [413.0, 313.0], [76.0, 313.0]'
# ...Line # 8 has text content 'factory investments to reduce costs in drug discovery, research' within bounding box '[76.0, 313.0], [427.0, 313.0], [427.0, 331.0], [76.0, 331.0]'
# ...Line # 9 has text content 'and development, and manufacturing and supply chain' within bounding box '[76.0, 331.0], [387.0, 331.0], [387.0, 349.0], [76.0, 348.0]'
# ...Line # 10 has text content 'management. Many life sciences organizations are also choosing' within bounding box '[76.0, 349.0], [441.0, 349.0], [441.0, 367.0], [76.0, 367.0]'
# ...Line # 11 has text content 'to stay with more virtual approaches in the "new normal" -' within bounding box '[76.0, 368.0], [405.0, 367.0], [405.0, 384.0], [76.0, 386.0]'
# ...Line # 12 has text content 'particularly in clinical trials and sales and marketing areas.' within bounding box '[76.0, 385.0], [395.0, 385.0], [395.0, 403.0], [76.0, 404.0]'
# ...Line # 13 has text content 'Enhancing the patient' within bounding box '[77.0, 422.0], [267.0, 423.0], [267.0, 447.0], [77.0, 445.0]'
# ...Line # 14 has text content 'and provider experience' within bounding box '[77.0, 446.0], [284.0, 446.0], [284.0, 470.0], [77.0, 470.0]'
# ...Line # 15 has text content 'Clinical trial sponsors are continually seeking to make clinical' within bounding box '[76.0, 481.0], [424.0, 481.0], [424.0, 499.0], [76.0, 499.0]'
# ...Line # 16 has text content 'trials faster and to improve the experience for patients and' within bounding box '[76.0, 499.0], [414.0, 500.0], [414.0, 517.0], [76.0, 516.0]'
# ...Line # 17 has text content 'physicians. The COVID-19 pandemic has accelerated the' within bounding box '[77.0, 517.0], [410.0, 517.0], [410.0, 535.0], [77.0, 535.0]'
# ...Line # 18 has text content 'adoption of decentralized clinical trials, with an increase in' within bounding box '[77.0, 535.0], [410.0, 535.0], [410.0, 552.0], [77.0, 553.0]'
# ...Line # 19 has text content 'trial activities conducted remotely and in participants' homes.' within bounding box '[76.0, 554.0], [428.0, 554.0], [428.0, 571.0], [76.0, 571.0]'
# ...Line # 20 has text content 'In a Mckinsey survey1 up to 98 percent of patients reported' within bounding box '[76.0, 572.0], [421.0, 572.0], [421.0, 590.0], [76.0, 590.0]'
# ...Line # 21 has text content 'satisfaction with telemedicine. In the same report, 72 percent of' within bounding box '[76.0, 590.0], [442.0, 590.0], [442.0, 608.0], [76.0, 607.0]'
# ...Line # 22 has text content 'physicians surveyed reported similar or better experiences with' within bounding box '[76.0, 609.0], [436.0, 608.0], [437.0, 626.0], [76.0, 626.0]'
# ...Line # 23 has text content 'remote engagement compared with in-person visits.' within bounding box '[75.0, 628.0], [376.0, 627.0], [376.0, 643.0], [75.0, 645.0]'
# ...Line # 24 has text content 'The shift of trial activities closer to patients has been enabled by' within bounding box '[74.0, 657.0], [444.0, 657.0], [444.0, 675.0], [74.0, 674.0]'
# ...Line # 25 has text content 'a myriad of evolving technologies and services (e.g., electronic' within bounding box '[76.0, 676.0], [438.0, 676.0], [438.0, 693.0], [76.0, 693.0]'
# ...Line # 26 has text content 'consent, telehealth and remote patient monitoring). The aim' within bounding box '[76.0, 693.0], [426.0, 694.0], [426.0, 710.0], [76.0, 710.0]'
# ...Line # 27 has text content 'to use technology to improve the patient experience and' within bounding box '[76.0, 712.0], [404.0, 712.0], [404.0, 728.0], [76.0, 729.0]'
# ...Line # 28 has text content 'convenience has also broadened trial access to reach a broader,' within bounding box '[77.0, 730.0], [441.0, 729.0], [441.0, 746.0], [77.0, 746.0]'
# ...Line # 29 has text content 'more diverse patient population.' within bounding box '[76.0, 748.0], [264.0, 748.0], [264.0, 765.0], [76.0, 765.0]'
# ...Line # 30 has text content '"It's an interesting and exciting time right now," said Keren' within bounding box '[72.0, 779.0], [406.0, 779.0], [406.0, 797.0], [72.0, 797.0]'
# ...Line # 31 has text content 'Priyadarshini, Regional Business Lead - Asia, Worldwide' within bounding box '[76.0, 797.0], [402.0, 797.0], [402.0, 814.0], [76.0, 815.0]'
# ...Line # 32 has text content 'Health, Microsoft. "It used to be that physicians were key.' within bounding box '[76.0, 814.0], [407.0, 815.0], [407.0, 833.0], [76.0, 831.0]'
# ...Line # 33 has text content 'Now, suddenly, patients are feeling empowered by technology.' within bounding box '[76.0, 833.0], [437.0, 834.0], [437.0, 851.0], [76.0, 850.0]'
# ...Line # 34 has text content 'Pharmaceutical companies and other life sciences companies' within bounding box '[76.0, 851.0], [429.0, 852.0], [429.0, 869.0], [76.0, 868.0]'
# ...Line # 35 has text content 'are realizing they have to pay attention to the patient' within bounding box '[76.0, 869.0], [383.0, 869.0], [383.0, 887.0], [76.0, 887.0]'
# ...Line # 36 has text content 'experience in addition to the physician experience."' within bounding box '[76.0, 888.0], [372.0, 887.0], [372.0, 905.0], [76.0, 905.0]'
# ...Line # 37 has text content 'Enhanced patient experiences can be delivered in many different' within bounding box '[76.0, 918.0], [441.0, 918.0], [442.0, 935.0], [76.0, 935.0]'
# ...Line # 38 has text content 'ways. One example of a life sciences product that leverages the' within bounding box '[76.0, 936.0], [432.0, 936.0], [432.0, 954.0], [76.0, 954.0]'
# ...Line # 39 has text content 'intelligent cloud to directly affect the patient experience is the' within bounding box '[76.0, 954.0], [424.0, 954.0], [424.0, 972.0], [76.0, 972.0]'
# ...Line # 40 has text content 'Tandem® Diabetes Care insulin pump. The Tandem® t:slim X2' within bounding box '[74.0, 972.0], [423.0, 972.0], [423.0, 989.0], [74.0, 989.0]'
# ...Line # 41 has text content 'insulin pump with Basal-IQ technology enables patients with' within bounding box '[76.0, 990.0], [416.0, 990.0], [416.0, 1007.0], [76.0, 1008.0]'
# ...Line # 42 has text content 'Type 1 diabetes to predict and prevent the low levels of blood' within bounding box '[74.0, 1008.0], [419.0, 1008.0], [419.0, 1025.0], [74.0, 1026.0]'
# ...Line # 43 has text content 'sugar that cause hypoglycemia.2 The algorithm-driven, software-' within bounding box '[77.0, 1027.0], [437.0, 1026.0], [438.0, 1044.0], [77.0, 1045.0]'
# ...Line # 44 has text content 'updatable pump improves the patient experience by automating' within bounding box '[76.0, 1045.0], [439.0, 1045.0], [439.0, 1062.0], [76.0, 1063.0]'
# ...Line # 45 has text content 'chronic disease management and eliminating the need for' within bounding box '[77.0, 1063.0], [403.0, 1063.0], [403.0, 1079.0], [77.0, 1080.0]'
# ...Line # 46 has text content 'constant finger pricks to check glucose levels.' within bounding box '[77.0, 1081.0], [333.0, 1080.0], [333.0, 1098.0], [77.0, 1098.0]'
# ...Line # 47 has text content 'Tandem was able to create and deploy this innovation by' within bounding box '[465.0, 240.0], [793.0, 240.0], [793.0, 259.0], [465.0, 257.0]'
# ...Line # 48 has text content 'leveraging the Al and machine learning capabilities of the' within bounding box '[466.0, 259.0], [802.0, 259.0], [802.0, 276.0], [466.0, 277.0]'
# ...Line # 49 has text content 'intelligent cloud. As Al and other technologies continue to' within bounding box '[467.0, 277.0], [808.0, 277.0], [808.0, 295.0], [467.0, 295.0]'
# ...Line # 50 has text content 'advance, potential use cases will multiply. "Speed to value is' within bounding box '[468.0, 295.0], [811.0, 295.0], [811.0, 312.0], [468.0, 313.0]'
# ...Line # 51 has text content 'going to continue to accelerate," said Lawry.' within bounding box '[468.0, 314.0], [723.0, 314.0], [723.0, 331.0], [468.0, 332.0]'
# ...Line # 52 has text content 'In addition to enhancing the patient experience,' within bounding box '[468.0, 344.0], [746.0, 345.0], [746.0, 362.0], [468.0, 361.0]'
# ...Line # 53 has text content 'pharmaceutical and other life sciences companies can' within bounding box '[468.0, 362.0], [778.0, 363.0], [778.0, 380.0], [468.0, 380.0]'
# ...Line # 54 has text content 'leverage advanced technologies to improve relationships with' within bounding box '[468.0, 380.0], [824.0, 380.0], [824.0, 398.0], [468.0, 398.0]'
# ...Line # 55 has text content 'providers. For example, COVID-19 is driving changes in the' within bounding box '[467.0, 398.0], [814.0, 398.0], [814.0, 416.0], [467.0, 416.0]'
# ...Line # 56 has text content 'way companies interact with clinicians. Prior to COVID-19,' within bounding box '[467.0, 417.0], [806.0, 416.0], [806.0, 433.0], [467.0, 435.0]'
# ...Line # 57 has text content '75 percent of physicians preferred in-person sales visits from' within bounding box '[467.0, 435.0], [816.0, 434.0], [816.0, 452.0], [467.0, 453.0]'
# ...Line # 58 has text content 'medtech reps; likewise, 77 percent of physicians preferred in-' within bounding box '[468.0, 452.0], [818.0, 452.0], [818.0, 470.0], [468.0, 470.0]'
# ...Line # 59 has text content 'person sales visits from pharma reps.3' within bounding box '[468.0, 471.0], [685.0, 471.0], [685.0, 488.0], [468.0, 489.0]'
# ...Line # 60 has text content 'Since the advent of COVID-19, however, physician' within bounding box '[468.0, 501.0], [771.0, 502.0], [770.0, 520.0], [468.0, 519.0]'
# ...Line # 61 has text content 'preferences are moving toward virtual visits. Only 53 percent' within bounding box '[468.0, 521.0], [827.0, 520.0], [827.0, 537.0], [468.0, 538.0]'
# ...Line # 62 has text content 'of physicians now express a preference for in-person visits' within bounding box '[468.0, 538.0], [811.0, 538.0], [811.0, 556.0], [468.0, 556.0]'
# ...Line # 63 has text content 'from medtech reps and only 40 percent prefer in-person visits' within bounding box '[468.0, 556.0], [835.0, 556.0], [835.0, 574.0], [468.0, 574.0]'
# ...Line # 64 has text content 'from pharma reps." That puts the onus on pharmaceutical and' within bounding box '[468.0, 574.0], [835.0, 574.0], [835.0, 592.0], [468.0, 592.0]'
# ...Line # 65 has text content 'life sciences organizations to deliver valuable and engaging' within bounding box '[469.0, 592.0], [819.0, 593.0], [819.0, 611.0], [469.0, 610.0]'
# ...Line # 66 has text content 'virtual visits to providers.' within bounding box '[467.0, 610.0], [616.0, 611.0], [616.0, 628.0], [467.0, 628.0]'
# ...Line # 67 has text content 'One way to do that is to leverage text analytics capabilities to' within bounding box '[468.0, 641.0], [822.0, 641.0], [822.0, 659.0], [468.0, 659.0]'
# ...Line # 68 has text content 'enhance the provider information stored in the organization's' within bounding box '[468.0, 659.0], [821.0, 659.0], [821.0, 677.0], [468.0, 677.0]'
# ...Line # 69 has text content 'customer relationship management (CRM) system. For' within bounding box '[469.0, 678.0], [788.0, 677.0], [788.0, 694.0], [469.0, 695.0]'
# ...Line # 70 has text content 'example, a rep setting up a visit with 'Dr. X' could run text' within bounding box '[469.0, 696.0], [802.0, 695.0], [802.0, 712.0], [469.0, 714.0]'
# ...Line # 71 has text content 'analytics on publicly available resources on the web to identify' within bounding box '[468.0, 714.0], [826.0, 713.0], [826.0, 731.0], [468.0, 731.0]'
# ...Line # 72 has text content 'on which specific topics Dr. X has been writing about and' within bounding box '[469.0, 731.0], [800.0, 731.0], [800.0, 749.0], [469.0, 749.0]'
# ...Line # 73 has text content 'commenting. "All kinds of publicly available information can' within bounding box '[469.0, 749.0], [813.0, 749.0], [813.0, 767.0], [469.0, 767.0]'
# ...Line # 74 has text content '"' within bounding box '[467.0, 794.0], [501.0, 794.0], [502.0, 821.0], [467.0, 820.0]'
# ...Line # 75 has text content 'All kinds of publicly' within bounding box '[466.0, 827.0], [644.0, 828.0], [644.0, 851.0], [466.0, 850.0]'
# ...Line # 76 has text content 'available information' within bounding box '[469.0, 856.0], [660.0, 856.0], [660.0, 877.0], [469.0, 877.0]'
# ...Line # 77 has text content 'can be mined with text' within bounding box '[469.0, 886.0], [674.0, 885.0], [674.0, 906.0], [469.0, 906.0]'
# ...Line # 78 has text content 'analytics technology,' within bounding box '[469.0, 914.0], [660.0, 915.0], [660.0, 937.0], [469.0, 936.0]'
# ...Line # 79 has text content 'which can be used to arm the' within bounding box '[468.0, 943.0], [730.0, 943.0], [730.0, 963.0], [468.0, 963.0]'
# ...Line # 80 has text content 'sales rep with relevant information even' within bounding box '[468.0, 972.0], [831.0, 971.0], [831.0, 992.0], [468.0, 993.0]'
# ...Line # 81 has text content 'before he or she meets the doctor. It's a' within bounding box '[469.0, 999.0], [823.0, 999.0], [823.0, 1020.0], [469.0, 1020.0]'
# ...Line # 82 has text content 'totally different, digital game now."' within bounding box '[469.0, 1028.0], [787.0, 1028.0], [787.0, 1051.0], [469.0, 1050.0]'
# ...Line # 83 has text content 'KEREN PRIYADARSHINI | Regional Business Lead - Asia,' within bounding box '[469.0, 1067.0], [761.0, 1067.0], [761.0, 1084.0], [469.0, 1083.0]'
# ...Line # 84 has text content 'Worldwide Health | Microsoft' within bounding box '[469.0, 1089.0], [615.0, 1089.0], [615.0, 1104.0], [469.0, 1104.0]'
# ...Line # 85 has text content 'EMBRACING DIGITAL TRANSFORMATION IN LIFE SCIENCES ORGANIZATIONS' within bounding box '[76.0, 1138.0], [451.0, 1138.0], [451.0, 1153.0], [76.0, 1154.0]'
# ...Line # 86 has text content '2' within bounding box '[810.0, 1137.0], [824.0, 1137.0], [823.0, 1155.0], [810.0, 1154.0]'
# ...Word 'While' has a confidence of 0.995
# ...Word 'healthcare' has a confidence of 0.993
# ...Word 'is' has a confidence of 0.947
# ...Word 'still' has a confidence of 0.992
# ...Word 'in' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'early' has a confidence of 0.994
# ...Word 'stages' has a confidence of 0.994
# ...Word 'of' has a confidence of 0.995
# ...Word 'its' has a confidence of 0.995
# ...Word 'Al' has a confidence of 0.903
# ...Word 'journey,' has a confidence of 0.989
# ...Word 'we' has a confidence of 0.996
# ...Word 'are' has a confidence of 0.995
# ...Word 'seeing' has a confidence of 0.994
# ...Word 'pharmaceutical' has a confidence of 0.981
# ...Word 'and' has a confidence of 0.995
# ...Word 'other' has a confidence of 0.993
# ...Word 'life' has a confidence of 0.972
# ...Word 'sciences' has a confidence of 0.99
# ...Word 'organizations' has a confidence of 0.979
# ...Word 'making' has a confidence of 0.994
# ...Word 'major' has a confidence of 0.994
# ...Word 'investments' has a confidence of 0.992
# ...Word 'in' has a confidence of 0.993
# ...Word 'Al' has a confidence of 0.9
# ...Word 'and' has a confidence of 0.996
# ...Word 'related' has a confidence of 0.994
# ...Word 'technologies."' has a confidence of 0.948
# ...Word 'TOM' has a confidence of 0.995
# ...Word 'LAWRY' has a confidence of 0.994
# ...Word '|' has a confidence of 0.937
# ...Word 'National' has a confidence of 0.975
# ...Word 'Director' has a confidence of 0.949
# ...Word 'for' has a confidence of 0.995
# ...Word 'Al,' has a confidence of 0.918
# ...Word 'Health' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.995
# ...Word 'Life' has a confidence of 0.989
# ...Word 'Sciences' has a confidence of 0.976
# ...Word '|' has a confidence of 0.968
# ...Word 'Microsoft' has a confidence of 0.963
# ...Word 'As' has a confidence of 0.996
# ...Word 'pharmaceutical' has a confidence of 0.984
# ...Word 'and' has a confidence of 0.996
# ...Word 'other' has a confidence of 0.993
# ...Word 'life' has a confidence of 0.992
# ...Word 'sciences' has a confidence of 0.99
# ...Word 'organizations' has a confidence of 0.97
# ...Word 'invest' has a confidence of 0.994
# ...Word 'in' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.995
# ...Word 'deploy' has a confidence of 0.995
# ...Word 'advanced' has a confidence of 0.993
# ...Word 'technologies,' has a confidence of 0.976
# ...Word 'they' has a confidence of 0.993
# ...Word 'are' has a confidence of 0.997
# ...Word 'beginning' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.995
# ...Word 'see' has a confidence of 0.995
# ...Word 'benefits' has a confidence of 0.992
# ...Word 'in' has a confidence of 0.995
# ...Word 'diverse' has a confidence of 0.993
# ...Word 'areas' has a confidence of 0.994
# ...Word 'across' has a confidence of 0.993
# ...Word 'their' has a confidence of 0.995
# ...Word 'organizations.' has a confidence of 0.981
# ...Word 'Companies' has a confidence of 0.993
# ...Word 'are' has a confidence of 0.995
# ...Word 'looking' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.996
# ...Word 'incorporate' has a confidence of 0.976
# ...Word 'automation' has a confidence of 0.982
# ...Word 'and' has a confidence of 0.995
# ...Word 'continuing' has a confidence of 0.99
# ...Word 'smart' has a confidence of 0.994
# ...Word 'factory' has a confidence of 0.995
# ...Word 'investments' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.997
# ...Word 'reduce' has a confidence of 0.994
# ...Word 'costs' has a confidence of 0.994
# ...Word 'in' has a confidence of 0.992
# ...Word 'drug' has a confidence of 0.984
# ...Word 'discovery,' has a confidence of 0.982
# ...Word 'research' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.995
# ...Word 'development,' has a confidence of 0.962
# ...Word 'and' has a confidence of 0.997
# ...Word 'manufacturing' has a confidence of 0.961
# ...Word 'and' has a confidence of 0.996
# ...Word 'supply' has a confidence of 0.994
# ...Word 'chain' has a confidence of 0.993
# ...Word 'management.' has a confidence of 0.985
# ...Word 'Many' has a confidence of 0.993
# ...Word 'life' has a confidence of 0.991
# ...Word 'sciences' has a confidence of 0.987
# ...Word 'organizations' has a confidence of 0.986
# ...Word 'are' has a confidence of 0.996
# ...Word 'also' has a confidence of 0.98
# ...Word 'choosing' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.995
# ...Word 'stay' has a confidence of 0.992
# ...Word 'with' has a confidence of 0.993
# ...Word 'more' has a confidence of 0.993
# ...Word 'virtual' has a confidence of 0.991
# ...Word 'approaches' has a confidence of 0.991
# ...Word 'in' has a confidence of 0.993
# ...Word 'the' has a confidence of 0.995
# ...Word '"new' has a confidence of 0.983
# ...Word 'normal"' has a confidence of 0.961
# ...Word '-' has a confidence of 0.994
# ...Word 'particularly' has a confidence of 0.979
# ...Word 'in' has a confidence of 0.995
# ...Word 'clinical' has a confidence of 0.978
# ...Word 'trials' has a confidence of 0.991
# ...Word 'and' has a confidence of 0.995
# ...Word 'sales' has a confidence of 0.994
# ...Word 'and' has a confidence of 0.963
# ...Word 'marketing' has a confidence of 0.963
# ...Word 'areas.' has a confidence of 0.993
# ...Word 'Enhancing' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.996
# ...Word 'patient' has a confidence of 0.973
# ...Word 'and' has a confidence of 0.995
# ...Word 'provider' has a confidence of 0.994
# ...Word 'experience' has a confidence of 0.993
# ...Word 'Clinical' has a confidence of 0.992
# ...Word 'trial' has a confidence of 0.993
# ...Word 'sponsors' has a confidence of 0.993
# ...Word 'are' has a confidence of 0.995
# ...Word 'continually' has a confidence of 0.99
# ...Word 'seeking' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.995
# ...Word 'make' has a confidence of 0.993
# ...Word 'clinical' has a confidence of 0.99
# ...Word 'trials' has a confidence of 0.993
# ...Word 'faster' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.997
# ...Word 'improve' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.995
# ...Word 'experience' has a confidence of 0.993
# ...Word 'for' has a confidence of 0.995
# ...Word 'patients' has a confidence of 0.994
# ...Word 'and' has a confidence of 0.996
# ...Word 'physicians.' has a confidence of 0.983
# ...Word 'The' has a confidence of 0.996
# ...Word 'COVID-19' has a confidence of 0.985
# ...Word 'pandemic' has a confidence of 0.989
# ...Word 'has' has a confidence of 0.995
# ...Word 'accelerated' has a confidence of 0.991
# ...Word 'the' has a confidence of 0.995
# ...Word 'adoption' has a confidence of 0.991
# ...Word 'of' has a confidence of 0.995
# ...Word 'decentralized' has a confidence of 0.984
# ...Word 'clinical' has a confidence of 0.981
# ...Word 'trials,' has a confidence of 0.989
# ...Word 'with' has a confidence of 0.993
# ...Word 'an' has a confidence of 0.997
# ...Word 'increase' has a confidence of 0.993
# ...Word 'in' has a confidence of 0.927
# ...Word 'trial' has a confidence of 0.993
# ...Word 'activities' has a confidence of 0.984
# ...Word 'conducted' has a confidence of 0.995
# ...Word 'remotely' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.995
# ...Word 'in' has a confidence of 0.995
# ...Word 'participants'' has a confidence of 0.976
# ...Word 'homes.' has a confidence of 0.975
# ...Word 'In' has a confidence of 0.995
# ...Word 'a' has a confidence of 0.995
# ...Word 'Mckinsey' has a confidence of 0.991
# ...Word 'survey1' has a confidence of 0.751
# ...Word 'up' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.996
# ...Word '98' has a confidence of 0.995
# ...Word 'percent' has a confidence of 0.994
# ...Word 'of' has a confidence of 0.995
# ...Word 'patients' has a confidence of 0.993
# ...Word 'reported' has a confidence of 0.979
# ...Word 'satisfaction' has a confidence of 0.985
# ...Word 'with' has a confidence of 0.993
# ...Word 'telemedicine.' has a confidence of 0.979
# ...Word 'In' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'same' has a confidence of 0.989
# ...Word 'report,' has a confidence of 0.967
# ...Word '72' has a confidence of 0.995
# ...Word 'percent' has a confidence of 0.972
# ...Word 'of' has a confidence of 0.995
# ...Word 'physicians' has a confidence of 0.99
# ...Word 'surveyed' has a confidence of 0.993
# ...Word 'reported' has a confidence of 0.993
# ...Word 'similar' has a confidence of 0.99
# ...Word 'or' has a confidence of 0.993
# ...Word 'better' has a confidence of 0.994
# ...Word 'experiences' has a confidence of 0.972
# ...Word 'with' has a confidence of 0.994
# ...Word 'remote' has a confidence of 0.995
# ...Word 'engagement' has a confidence of 0.994
# ...Word 'compared' has a confidence of 0.994
# ...Word 'with' has a confidence of 0.993
# ...Word 'in-person' has a confidence of 0.99
# ...Word 'visits.' has a confidence of 0.993
# ...Word 'The' has a confidence of 0.997
# ...Word 'shift' has a confidence of 0.992
# ...Word 'of' has a confidence of 0.995
# ...Word 'trial' has a confidence of 0.995
# ...Word 'activities' has a confidence of 0.979
# ...Word 'closer' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.996
# ...Word 'patients' has a confidence of 0.99
# ...Word 'has' has a confidence of 0.995
# ...Word 'been' has a confidence of 0.982
# ...Word 'enabled' has a confidence of 0.992
# ...Word 'by' has a confidence of 0.995
# ...Word 'a' has a confidence of 0.993
# ...Word 'myriad' has a confidence of 0.994
# ...Word 'of' has a confidence of 0.995
# ...Word 'evolving' has a confidence of 0.992
# ...Word 'technologies' has a confidence of 0.977
# ...Word 'and' has a confidence of 0.995
# ...Word 'services' has a confidence of 0.985
# ...Word '(e.g.,' has a confidence of 0.964
# ...Word 'electronic' has a confidence of 0.993
# ...Word 'consent,' has a confidence of 0.986
# ...Word 'telehealth' has a confidence of 0.994
# ...Word 'and' has a confidence of 0.995
# ...Word 'remote' has a confidence of 0.994
# ...Word 'patient' has a confidence of 0.993
# ...Word 'monitoring).' has a confidence of 0.986
# ...Word 'The' has a confidence of 0.997
# ...Word 'aim' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.996
# ...Word 'use' has a confidence of 0.996
# ...Word 'technology' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.998
# ...Word 'improve' has a confidence of 0.993
# ...Word 'the' has a confidence of 0.996
# ...Word 'patient' has a confidence of 0.994
# ...Word 'experience' has a confidence of 0.992
# ...Word 'and' has a confidence of 0.996
# ...Word 'convenience' has a confidence of 0.993
# ...Word 'has' has a confidence of 0.995
# ...Word 'also' has a confidence of 0.99
# ...Word 'broadened' has a confidence of 0.993
# ...Word 'trial' has a confidence of 0.994
# ...Word 'access' has a confidence of 0.99
# ...Word 'to' has a confidence of 0.996
# ...Word 'reach' has a confidence of 0.993
# ...Word 'a' has a confidence of 0.996
# ...Word 'broader,' has a confidence of 0.961
# ...Word 'more' has a confidence of 0.992
# ...Word 'diverse' has a confidence of 0.994
# ...Word 'patient' has a confidence of 0.993
# ...Word 'population.' has a confidence of 0.961
# ...Word '"It's' has a confidence of 0.862
# ...Word 'an' has a confidence of 0.995
# ...Word 'interesting' has a confidence of 0.985
# ...Word 'and' has a confidence of 0.995
# ...Word 'exciting' has a confidence of 0.994
# ...Word 'time' has a confidence of 0.982
# ...Word 'right' has a confidence of 0.994
# ...Word 'now,"' has a confidence of 0.961
# ...Word 'said' has a confidence of 0.992
# ...Word 'Keren' has a confidence of 0.995
# ...Word 'Priyadarshini,' has a confidence of 0.982
# ...Word 'Regional' has a confidence of 0.993
# ...Word 'Business' has a confidence of 0.993
# ...Word 'Lead' has a confidence of 0.992
# ...Word '-' has a confidence of 0.995
# ...Word 'Asia,' has a confidence of 0.993
# ...Word 'Worldwide' has a confidence of 0.991
# ...Word 'Health,' has a confidence of 0.991
# ...Word 'Microsoft.' has a confidence of 0.993
# ...Word '"It' has a confidence of 0.894
# ...Word 'used' has a confidence of 0.99
# ...Word 'to' has a confidence of 0.995
# ...Word 'be' has a confidence of 0.995
# ...Word 'that' has a confidence of 0.993
# ...Word 'physicians' has a confidence of 0.99
# ...Word 'were' has a confidence of 0.993
# ...Word 'key.' has a confidence of 0.93
# ...Word 'Now,' has a confidence of 0.989
# ...Word 'suddenly,' has a confidence of 0.984
# ...Word 'patients' has a confidence of 0.993
# ...Word 'are' has a confidence of 0.995
# ...Word 'feeling' has a confidence of 0.992
# ...Word 'empowered' has a confidence of 0.993
# ...Word 'by' has a confidence of 0.995
# ...Word 'technology.' has a confidence of 0.925
# ...Word 'Pharmaceutical' has a confidence of 0.983
# ...Word 'companies' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.996
# ...Word 'other' has a confidence of 0.995
# ...Word 'life' has a confidence of 0.967
# ...Word 'sciences' has a confidence of 0.993
# ...Word 'companies' has a confidence of 0.992
# ...Word 'are' has a confidence of 0.995
# ...Word 'realizing' has a confidence of 0.988
# ...Word 'they' has a confidence of 0.992
# ...Word 'have' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.995
# ...Word 'pay' has a confidence of 0.995
# ...Word 'attention' has a confidence of 0.991
# ...Word 'to' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'patient' has a confidence of 0.994
# ...Word 'experience' has a confidence of 0.961
# ...Word 'in' has a confidence of 0.928
# ...Word 'addition' has a confidence of 0.99
# ...Word 'to' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'physician' has a confidence of 0.984
# ...Word 'experience."' has a confidence of 0.961
# ...Word 'Enhanced' has a confidence of 0.994
# ...Word 'patient' has a confidence of 0.994
# ...Word 'experiences' has a confidence of 0.99
# ...Word 'can' has a confidence of 0.995
# ...Word 'be' has a confidence of 0.995
# ...Word 'delivered' has a confidence of 0.972
# ...Word 'in' has a confidence of 0.995
# ...Word 'many' has a confidence of 0.993
# ...Word 'different' has a confidence of 0.976
# ...Word 'ways.' has a confidence of 0.993
# ...Word 'One' has a confidence of 0.995
# ...Word 'example' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.995
# ...Word 'a' has a confidence of 0.995
# ...Word 'life' has a confidence of 0.99
# ...Word 'sciences' has a confidence of 0.945
# ...Word 'product' has a confidence of 0.992
# ...Word 'that' has a confidence of 0.992
# ...Word 'leverages' has a confidence of 0.961
# ...Word 'the' has a confidence of 0.996
# ...Word 'intelligent' has a confidence of 0.98
# ...Word 'cloud' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.995
# ...Word 'directly' has a confidence of 0.991
# ...Word 'affect' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.995
# ...Word 'patient' has a confidence of 0.993
# ...Word 'experience' has a confidence of 0.962
# ...Word 'is' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'Tandem®' has a confidence of 0.696
# ...Word 'Diabetes' has a confidence of 0.98
# ...Word 'Care' has a confidence of 0.993
# ...Word 'insulin' has a confidence of 0.99
# ...Word 'pump.' has a confidence of 0.992
# ...Word 'The' has a confidence of 0.995
# ...Word 'Tandem®' has a confidence of 0.621
# ...Word 't:slim' has a confidence of 0.945
# ...Word 'X2' has a confidence of 0.995
# ...Word 'insulin' has a confidence of 0.993
# ...Word 'pump' has a confidence of 0.99
# ...Word 'with' has a confidence of 0.993
# ...Word 'Basal-IQ' has a confidence of 0.973
# ...Word 'technology' has a confidence of 0.987
# ...Word 'enables' has a confidence of 0.993
# ...Word 'patients' has a confidence of 0.987
# ...Word 'with' has a confidence of 0.993
# ...Word 'Type' has a confidence of 0.993
# ...Word '1' has a confidence of 0.983
# ...Word 'diabetes' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.994
# ...Word 'predict' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.962
# ...Word 'prevent' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.997
# ...Word 'low' has a confidence of 0.995
# ...Word 'levels' has a confidence of 0.945
# ...Word 'of' has a confidence of 0.995
# ...Word 'blood' has a confidence of 0.994
# ...Word 'sugar' has a confidence of 0.995
# ...Word 'that' has a confidence of 0.988
# ...Word 'cause' has a confidence of 0.994
# ...Word 'hypoglycemia.2' has a confidence of 0.963
# ...Word 'The' has a confidence of 0.997
# ...Word 'algorithm-driven,' has a confidence of 0.968
# ...Word 'software-' has a confidence of 0.973
# ...Word 'updatable' has a confidence of 0.989
# ...Word 'pump' has a confidence of 0.99
# ...Word 'improves' has a confidence of 0.993
# ...Word 'the' has a confidence of 0.995
# ...Word 'patient' has a confidence of 0.993
# ...Word 'experience' has a confidence of 0.987
# ...Word 'by' has a confidence of 0.995
# ...Word 'automating' has a confidence of 0.991
# ...Word 'chronic' has a confidence of 0.994
# ...Word 'disease' has a confidence of 0.993
# ...Word 'management' has a confidence of 0.99
# ...Word 'and' has a confidence of 0.996
# ...Word 'eliminating' has a confidence of 0.991
# ...Word 'the' has a confidence of 0.997
# ...Word 'need' has a confidence of 0.993
# ...Word 'for' has a confidence of 0.995
# ...Word 'constant' has a confidence of 0.994
# ...Word 'finger' has a confidence of 0.994
# ...Word 'pricks' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.995
# ...Word 'check' has a confidence of 0.995
# ...Word 'glucose' has a confidence of 0.993
# ...Word 'levels.' has a confidence of 0.944
# ...Word 'Tandem' has a confidence of 0.993
# ...Word 'was' has a confidence of 0.995
# ...Word 'able' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.995
# ...Word 'create' has a confidence of 0.994
# ...Word 'and' has a confidence of 0.995
# ...Word 'deploy' has a confidence of 0.994
# ...Word 'this' has a confidence of 0.989
# ...Word 'innovation' has a confidence of 0.989
# ...Word 'by' has a confidence of 0.995
# ...Word 'leveraging' has a confidence of 0.975
# ...Word 'the' has a confidence of 0.995
# ...Word 'Al' has a confidence of 0.937
# ...Word 'and' has a confidence of 0.995
# ...Word 'machine' has a confidence of 0.991
# ...Word 'learning' has a confidence of 0.962
# ...Word 'capabilities' has a confidence of 0.979
# ...Word 'of' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'intelligent' has a confidence of 0.989
# ...Word 'cloud.' has a confidence of 0.989
# ...Word 'As' has a confidence of 0.984
# ...Word 'Al' has a confidence of 0.912
# ...Word 'and' has a confidence of 0.996
# ...Word 'other' has a confidence of 0.994
# ...Word 'technologies' has a confidence of 0.987
# ...Word 'continue' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.995
# ...Word 'advance,' has a confidence of 0.97
# ...Word 'potential' has a confidence of 0.992
# ...Word 'use' has a confidence of 0.993
# ...Word 'cases' has a confidence of 0.995
# ...Word 'will' has a confidence of 0.992
# ...Word 'multiply.' has a confidence of 0.967
# ...Word '"Speed' has a confidence of 0.944
# ...Word 'to' has a confidence of 0.995
# ...Word 'value' has a confidence of 0.982
# ...Word 'is' has a confidence of 0.995
# ...Word 'going' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.995
# ...Word 'continue' has a confidence of 0.99
# ...Word 'to' has a confidence of 0.995
# ...Word 'accelerate,"' has a confidence of 0.945
# ...Word 'said' has a confidence of 0.99
# ...Word 'Lawry.' has a confidence of 0.93
# ...Word 'In' has a confidence of 0.99
# ...Word 'addition' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.995
# ...Word 'enhancing' has a confidence of 0.993
# ...Word 'the' has a confidence of 0.995
# ...Word 'patient' has a confidence of 0.994
# ...Word 'experience,' has a confidence of 0.99
# ...Word 'pharmaceutical' has a confidence of 0.963
# ...Word 'and' has a confidence of 0.995
# ...Word 'other' has a confidence of 0.995
# ...Word 'life' has a confidence of 0.99
# ...Word 'sciences' has a confidence of 0.993
# ...Word 'companies' has a confidence of 0.992
# ...Word 'can' has a confidence of 0.996
# ...Word 'leverage' has a confidence of 0.992
# ...Word 'advanced' has a confidence of 0.993
# ...Word 'technologies' has a confidence of 0.983
# ...Word 'to' has a confidence of 0.996
# ...Word 'improve' has a confidence of 0.994
# ...Word 'relationships' has a confidence of 0.973
# ...Word 'with' has a confidence of 0.993
# ...Word 'providers.' has a confidence of 0.975
# ...Word 'For' has a confidence of 0.995
# ...Word 'example,' has a confidence of 0.974
# ...Word 'COVID-19' has a confidence of 0.987
# ...Word 'is' has a confidence of 0.993
# ...Word 'driving' has a confidence of 0.994
# ...Word 'changes' has a confidence of 0.993
# ...Word 'in' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'way' has a confidence of 0.996
# ...Word 'companies' has a confidence of 0.99
# ...Word 'interact' has a confidence of 0.993
# ...Word 'with' has a confidence of 0.992
# ...Word 'clinicians.' has a confidence of 0.957
# ...Word 'Prior' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.995
# ...Word 'COVID-19,' has a confidence of 0.989
# ...Word '75' has a confidence of 0.995
# ...Word 'percent' has a confidence of 0.982
# ...Word 'of' has a confidence of 0.996
# ...Word 'physicians' has a confidence of 0.98
# ...Word 'preferred' has a confidence of 0.99
# ...Word 'in-person' has a confidence of 0.991
# ...Word 'sales' has a confidence of 0.994
# ...Word 'visits' has a confidence of 0.99
# ...Word 'from' has a confidence of 0.993
# ...Word 'medtech' has a confidence of 0.994
# ...Word 'reps;' has a confidence of 0.993
# ...Word 'likewise,' has a confidence of 0.991
# ...Word '77' has a confidence of 0.958
# ...Word 'percent' has a confidence of 0.994
# ...Word 'of' has a confidence of 0.995
# ...Word 'physicians' has a confidence of 0.979
# ...Word 'preferred' has a confidence of 0.989
# ...Word 'in-' has a confidence of 0.995
# ...Word 'person' has a confidence of 0.995
# ...Word 'sales' has a confidence of 0.994
# ...Word 'visits' has a confidence of 0.993
# ...Word 'from' has a confidence of 0.993
# ...Word 'pharma' has a confidence of 0.991
# ...Word 'reps.3' has a confidence of 0.959
# ...Word 'Since' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'advent' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.995
# ...Word 'COVID-19,' has a confidence of 0.963
# ...Word 'however,' has a confidence of 0.973
# ...Word 'physician' has a confidence of 0.991
# ...Word 'preferences' has a confidence of 0.962
# ...Word 'are' has a confidence of 0.995
# ...Word 'moving' has a confidence of 0.994
# ...Word 'toward' has a confidence of 0.995
# ...Word 'virtual' has a confidence of 0.975
# ...Word 'visits.' has a confidence of 0.993
# ...Word 'Only' has a confidence of 0.992
# ...Word '53' has a confidence of 0.995
# ...Word 'percent' has a confidence of 0.994
# ...Word 'of' has a confidence of 0.995
# ...Word 'physicians' has a confidence of 0.992
# ...Word 'now' has a confidence of 0.996
# ...Word 'express' has a confidence of 0.993
# ...Word 'a' has a confidence of 0.995
# ...Word 'preference' has a confidence of 0.98
# ...Word 'for' has a confidence of 0.983
# ...Word 'in-person' has a confidence of 0.973
# ...Word 'visits' has a confidence of 0.993
# ...Word 'from' has a confidence of 0.993
# ...Word 'medtech' has a confidence of 0.994
# ...Word 'reps' has a confidence of 0.992
# ...Word 'and' has a confidence of 0.995
# ...Word 'only' has a confidence of 0.993
# ...Word '40' has a confidence of 0.995
# ...Word 'percent' has a confidence of 0.994
# ...Word 'prefer' has a confidence of 0.994
# ...Word 'in-person' has a confidence of 0.991
# ...Word 'visits' has a confidence of 0.993
# ...Word 'from' has a confidence of 0.993
# ...Word 'pharma' has a confidence of 0.992
# ...Word 'reps."' has a confidence of 0.565
# ...Word 'That' has a confidence of 0.992
# ...Word 'puts' has a confidence of 0.975
# ...Word 'the' has a confidence of 0.995
# ...Word 'onus' has a confidence of 0.991
# ...Word 'on' has a confidence of 0.995
# ...Word 'pharmaceutical' has a confidence of 0.981
# ...Word 'and' has a confidence of 0.992
# ...Word 'life' has a confidence of 0.991
# ...Word 'sciences' has a confidence of 0.993
# ...Word 'organizations' has a confidence of 0.986
# ...Word 'to' has a confidence of 0.995
# ...Word 'deliver' has a confidence of 0.994
# ...Word 'valuable' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.996
# ...Word 'engaging' has a confidence of 0.993
# ...Word 'virtual' has a confidence of 0.993
# ...Word 'visits' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.995
# ...Word 'providers.' has a confidence of 0.961
# ...Word 'One' has a confidence of 0.996
# ...Word 'way' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.996
# ...Word 'do' has a confidence of 0.995
# ...Word 'that' has a confidence of 0.991
# ...Word 'is' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.996
# ...Word 'leverage' has a confidence of 0.992
# ...Word 'text' has a confidence of 0.99
# ...Word 'analytics' has a confidence of 0.994
# ...Word 'capabilities' has a confidence of 0.979
# ...Word 'to' has a confidence of 0.996
# ...Word 'enhance' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.995
# ...Word 'provider' has a confidence of 0.991
# ...Word 'information' has a confidence of 0.985
# ...Word 'stored' has a confidence of 0.994
# ...Word 'in' has a confidence of 0.974
# ...Word 'the' has a confidence of 0.995
# ...Word 'organization's' has a confidence of 0.974
# ...Word 'customer' has a confidence of 0.994
# ...Word 'relationship' has a confidence of 0.991
# ...Word 'management' has a confidence of 0.992
# ...Word '(CRM)' has a confidence of 0.994
# ...Word 'system.' has a confidence of 0.994
# ...Word 'For' has a confidence of 0.997
# ...Word 'example,' has a confidence of 0.987
# ...Word 'a' has a confidence of 0.995
# ...Word 'rep' has a confidence of 0.995
# ...Word 'setting' has a confidence of 0.989
# ...Word 'up' has a confidence of 0.995
# ...Word 'a' has a confidence of 0.995
# ...Word 'visit' has a confidence of 0.99
# ...Word 'with' has a confidence of 0.992
# ...Word ''Dr.' has a confidence of 0.961
# ...Word 'X'' has a confidence of 0.948
# ...Word 'could' has a confidence of 0.995
# ...Word 'run' has a confidence of 0.995
# ...Word 'text' has a confidence of 0.992
# ...Word 'analytics' has a confidence of 0.981
# ...Word 'on' has a confidence of 0.995
# ...Word 'publicly' has a confidence of 0.984
# ...Word 'available' has a confidence of 0.962
# ...Word 'resources' has a confidence of 0.961
# ...Word 'on' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.995
# ...Word 'web' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.995
# ...Word 'identify' has a confidence of 0.991
# ...Word 'on' has a confidence of 0.995
# ...Word 'which' has a confidence of 0.994
# ...Word 'specific' has a confidence of 0.99
# ...Word 'topics' has a confidence of 0.993
# ...Word 'Dr.' has a confidence of 0.995
# ...Word 'X' has a confidence of 0.995
# ...Word 'has' has a confidence of 0.994
# ...Word 'been' has a confidence of 0.992
# ...Word 'writing' has a confidence of 0.993
# ...Word 'about' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.995
# ...Word 'commenting.' has a confidence of 0.991
# ...Word '"All' has a confidence of 0.972
# ...Word 'kinds' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.995
# ...Word 'publicly' has a confidence of 0.983
# ...Word 'available' has a confidence of 0.993
# ...Word 'information' has a confidence of 0.982
# ...Word 'can' has a confidence of 0.995
# ...Word '"' has a confidence of 0.577
# ...Word 'All' has a confidence of 0.995
# ...Word 'kinds' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.997
# ...Word 'publicly' has a confidence of 0.995
# ...Word 'available' has a confidence of 0.948
# ...Word 'information' has a confidence of 0.991
# ...Word 'can' has a confidence of 0.993
# ...Word 'be' has a confidence of 0.994
# ...Word 'mined' has a confidence of 0.995
# ...Word 'with' has a confidence of 0.993
# ...Word 'text' has a confidence of 0.993
# ...Word 'analytics' has a confidence of 0.994
# ...Word 'technology,' has a confidence of 0.972
# ...Word 'which' has a confidence of 0.995
# ...Word 'can' has a confidence of 0.994
# ...Word 'be' has a confidence of 0.995
# ...Word 'used' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.996
# ...Word 'arm' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'sales' has a confidence of 0.995
# ...Word 'rep' has a confidence of 0.997
# ...Word 'with' has a confidence of 0.993
# ...Word 'relevant' has a confidence of 0.993
# ...Word 'information' has a confidence of 0.993
# ...Word 'even' has a confidence of 0.992
# ...Word 'before' has a confidence of 0.995
# ...Word 'he' has a confidence of 0.995
# ...Word 'or' has a confidence of 0.995
# ...Word 'she' has a confidence of 0.997
# ...Word 'meets' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.997
# ...Word 'doctor.' has a confidence of 0.993
# ...Word 'It's' has a confidence of 0.968
# ...Word 'a' has a confidence of 0.993
# ...Word 'totally' has a confidence of 0.993
# ...Word 'different,' has a confidence of 0.992
# ...Word 'digital' has a confidence of 0.993
# ...Word 'game' has a confidence of 0.99
# ...Word 'now."' has a confidence of 0.924
# ...Word 'KEREN' has a confidence of 0.995
# ...Word 'PRIYADARSHINI' has a confidence of 0.984
# ...Word '|' has a confidence of 0.969
# ...Word 'Regional' has a confidence of 0.973
# ...Word 'Business' has a confidence of 0.961
# ...Word 'Lead' has a confidence of 0.989
# ...Word '-' has a confidence of 0.961
# ...Word 'Asia,' has a confidence of 0.984
# ...Word 'Worldwide' has a confidence of 0.983
# ...Word 'Health' has a confidence of 0.993
# ...Word '|' has a confidence of 0.97
# ...Word 'Microsoft' has a confidence of 0.948
# ...Word 'EMBRACING' has a confidence of 0.992
# ...Word 'DIGITAL' has a confidence of 0.99
# ...Word 'TRANSFORMATION' has a confidence of 0.974
# ...Word 'IN' has a confidence of 0.993
# ...Word 'LIFE' has a confidence of 0.99
# ...Word 'SCIENCES' has a confidence of 0.962
# ...Word 'ORGANIZATIONS' has a confidence of 0.962
# ...Word '2' has a confidence of 0.992
# ----------------------------------------

# %% [markdown]
# ## 레이아웃 모델

# %%
"""
This code sample shows Prebuilt Read operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://learn.microsoft.com/azure/applied-ai-services/form-recognizer/quickstarts/get-started-v3-sdk-rest-api?view=doc-intel-3.1.0&pivots=programming-language-python
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

# -> pip install azure-ai-formrecognizer
"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
endpoint = "https://b040-document.cognitiveservices.azure.com/"
key = "9njyuOpUp5Z5pFEZmGom6Yt8lMSP4FnVSKeHm981aJnUUCfFC5VPJQQJ99ALAC4f1cMXJ3w3AAALACOGqCyV"

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

def analyze_read():
    # sample document
    #formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"
    formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/rest-api/layout.png"
    
    document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    poller = document_analysis_client.begin_analyze_document_from_url(
            "prebuilt-read", formUrl)
    result = poller.result()

    print ("Document contains content: ", result.content)
    
    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")


if __name__ == "__main__":
    analyze_read()
# Out:
# Document contains content:  555
# Liberty's Delightful Sinful Bakery & Café 765 Halifax St. Clearwater, FL 33756
# Our reference: 3456623 Your reference: 2334566
# Received from: 8556 Indian Summer Ave. New Haven, CT 06511
# Liberty booking contact 40 River Street East Northport, NY 11731
# Name Summer River Tel. 34456632 E-mail email6@libertydelightfulsinful.com
# Booking Confirmation - ORIGINAL
# Our reference:
# 3456623
# Your reference:
# 2334566
# BL/NO:
# EURH234
# Summary:
# 45×72
# Booking date:
# 05-Dec-2018 Contract No: 334566
# Export:
# Common
# Export empty pick up depot(s)
# 97 Morris Lane Sterling Heights, MI 48310
# From
# To
# 118 Queen Street
# Hoboken, NJ 07030
# 52 West Trenton St.
# Harleysville, PA
# 19438
# 75 Fawn Street
# Peabody, MA 01960
# Opt. A
# By
# cause science slow
# 9 Ketch Harbour
# Ave.
# Vincentown, NJ
# ETD
# 09-Dec-2018
# 19:00
# tone late spoken
# 12-Dec-2018
# 10:00
# Deadline
# Table
# Harleysville
# (PA)
# Flight
# Harleysville
# 08-Dec-2019
# 13:00
# Round
# 09-Dec-2019
# (PA)
# Harleysville
# (PA)
# Accent
# Harleysville
# 10-Dec-2019
# (PA)
# Monkey
# Harleysville
# (PA)
# 11-Dec-2019
# Location
# Harleysville
# 11-Dec-2019
# Route
# (PA)
# Date/Time (local)
# 08-Dec-2019
# Opt. B
# ETA
# 09-Dec-2020
# 11:00
# 19-Dec-2020
# Required action
# Two more days and all his problems would be solved.
# Peanuts don't grow on
# trees.
# Document contains handwritten content
# ----Analyzing Read from page #1----
# Page has width: 909.0 and height: 1177.0, measured with unit: pixel
# ...Line # 0 has text content '555' within bounding box '[789.0, 20.0], [821.0, 20.0], [821.0, 45.0], [789.0, 45.0]'
# ...Line # 1 has text content 'Liberty's Delightful Sinful Bakery & Café' within bounding box '[46.0, 49.0], [366.0, 48.0], [366.0, 69.0], [46.0, 69.0]'
# ...Line # 2 has text content '765 Halifax St. Clearwater, FL 33756' within bounding box '[47.0, 69.0], [321.0, 69.0], [321.0, 88.0], [47.0, 88.0]'
# ...Line # 3 has text content 'Our reference: 3456623' within bounding box '[47.0, 101.0], [211.0, 101.0], [211.0, 119.0], [47.0, 119.0]'
# ...Line # 4 has text content 'Your reference: 2334566' within bounding box '[255.0, 101.0], [425.0, 101.0], [425.0, 119.0], [255.0, 119.0]'
# ...Line # 5 has text content 'Received from:' within bounding box '[46.0, 167.0], [169.0, 168.0], [169.0, 186.0], [46.0, 186.0]'
# ...Line # 6 has text content '8556 Indian Summer Ave.' within bounding box '[46.0, 188.0], [240.0, 188.0], [240.0, 208.0], [46.0, 207.0]'
# ...Line # 7 has text content 'New Haven, CT 06511' within bounding box '[46.0, 208.0], [215.0, 207.0], [215.0, 227.0], [46.0, 227.0]'
# ...Line # 8 has text content 'Liberty booking contact' within bounding box '[600.0, 174.0], [791.0, 174.0], [791.0, 194.0], [600.0, 194.0]'
# ...Line # 9 has text content '40 River Street' within bounding box '[599.0, 195.0], [715.0, 195.0], [715.0, 214.0], [599.0, 214.0]'
# ...Line # 10 has text content 'East Northport, NY 11731' within bounding box '[599.0, 214.0], [791.0, 214.0], [791.0, 235.0], [600.0, 235.0]'
# ...Line # 11 has text content 'Name Summer River' within bounding box '[46.0, 249.0], [204.0, 249.0], [204.0, 268.0], [46.0, 268.0]'
# ...Line # 12 has text content 'Tel. 34456632' within bounding box '[47.0, 270.0], [154.0, 270.0], [154.0, 289.0], [47.0, 288.0]'
# ...Line # 13 has text content 'E-mail email6@libertydelightfulsinful.com' within bounding box '[46.0, 290.0], [356.0, 290.0], [356.0, 310.0], [46.0, 310.0]'
# ...Line # 14 has text content 'Booking Confirmation - ORIGINAL' within bounding box '[48.0, 354.0], [494.0, 353.0], [495.0, 381.0], [48.0, 384.0]'
# ...Line # 15 has text content 'Our reference:' within bounding box '[70.0, 411.0], [178.0, 412.0], [178.0, 429.0], [70.0, 428.0]'
# ...Line # 16 has text content '3456623' within bounding box '[204.0, 408.0], [287.0, 408.0], [288.0, 428.0], [204.0, 428.0]'
# ...Line # 17 has text content 'Your reference:' within bounding box '[71.0, 433.0], [185.0, 434.0], [185.0, 450.0], [71.0, 450.0]'
# ...Line # 18 has text content '2334566' within bounding box '[201.0, 433.0], [269.0, 433.0], [269.0, 449.0], [201.0, 450.0]'
# ...Line # 19 has text content 'BL/NO:' within bounding box '[71.0, 453.0], [125.0, 453.0], [125.0, 469.0], [71.0, 469.0]'
# ...Line # 20 has text content 'EURH234' within bounding box '[203.0, 453.0], [278.0, 453.0], [278.0, 470.0], [203.0, 470.0]'
# ...Line # 21 has text content 'Summary:' within bounding box '[71.0, 474.0], [148.0, 476.0], [147.0, 494.0], [71.0, 491.0]'
# ...Line # 22 has text content '45×72' within bounding box '[201.0, 474.0], [248.0, 474.0], [248.0, 491.0], [201.0, 491.0]'
# ...Line # 23 has text content 'Booking date:' within bounding box '[502.0, 428.0], [615.0, 428.0], [615.0, 451.0], [502.0, 451.0]'
# ...Line # 24 has text content '05-Dec-2018' within bounding box '[620.0, 428.0], [718.0, 427.0], [718.0, 450.0], [620.0, 450.0]'
# ...Line # 25 has text content 'Contract No:' within bounding box '[502.0, 450.0], [598.0, 450.0], [597.0, 468.0], [502.0, 467.0]'
# ...Line # 26 has text content '334566' within bounding box '[621.0, 450.0], [681.0, 449.0], [681.0, 467.0], [621.0, 467.0]'
# ...Line # 27 has text content 'Export:' within bounding box '[71.0, 536.0], [123.0, 536.0], [123.0, 554.0], [71.0, 553.0]'
# ...Line # 28 has text content 'Common' within bounding box '[187.0, 535.0], [256.0, 536.0], [255.0, 552.0], [187.0, 551.0]'
# ...Line # 29 has text content 'Export empty pick up depot(s)' within bounding box '[48.0, 599.0], [286.0, 599.0], [286.0, 620.0], [48.0, 620.0]'
# ...Line # 30 has text content '97 Morris Lane' within bounding box '[46.0, 640.0], [160.0, 640.0], [160.0, 659.0], [46.0, 659.0]'
# ...Line # 31 has text content 'Sterling Heights, MI 48310' within bounding box '[47.0, 660.0], [245.0, 659.0], [245.0, 680.0], [47.0, 680.0]'
# ...Line # 32 has text content 'From' within bounding box '[55.0, 695.0], [95.0, 695.0], [96.0, 710.0], [55.0, 709.0]'
# ...Line # 33 has text content 'To' within bounding box '[212.0, 695.0], [232.0, 694.0], [232.0, 710.0], [213.0, 709.0]'
# ...Line # 34 has text content '118 Queen Street' within bounding box '[57.0, 712.0], [177.0, 712.0], [177.0, 728.0], [57.0, 728.0]'
# ...Line # 35 has text content 'Hoboken, NJ 07030' within bounding box '[55.0, 729.0], [191.0, 728.0], [191.0, 744.0], [55.0, 745.0]'
# ...Line # 36 has text content '52 West Trenton St.' within bounding box '[211.0, 711.0], [347.0, 711.0], [347.0, 728.0], [211.0, 728.0]'
# ...Line # 37 has text content 'Harleysville, PA' within bounding box '[212.0, 729.0], [320.0, 729.0], [320.0, 745.0], [212.0, 746.0]'
# ...Line # 38 has text content '19438' within bounding box '[213.0, 748.0], [256.0, 747.0], [256.0, 762.0], [213.0, 762.0]'
# ...Line # 39 has text content '75 Fawn Street' within bounding box '[212.0, 765.0], [317.0, 765.0], [317.0, 781.0], [212.0, 781.0]'
# ...Line # 40 has text content 'Peabody, MA 01960' within bounding box '[212.0, 781.0], [350.0, 781.0], [350.0, 799.0], [212.0, 799.0]'
# ...Line # 41 has text content 'Opt. A' within bounding box '[539.0, 491.0], [592.0, 490.0], [593.0, 514.0], [539.0, 513.0]'
# ...Line # 42 has text content 'By' within bounding box '[368.0, 695.0], [389.0, 695.0], [390.0, 711.0], [369.0, 710.0]'
# ...Line # 43 has text content 'cause science slow' within bounding box '[368.0, 713.0], [500.0, 712.0], [500.0, 729.0], [368.0, 729.0]'
# ...Line # 44 has text content '9 Ketch Harbour' within bounding box '[54.0, 765.0], [167.0, 765.0], [167.0, 781.0], [54.0, 781.0]'
# ...Line # 45 has text content 'Ave.' within bounding box '[55.0, 783.0], [86.0, 783.0], [86.0, 797.0], [55.0, 797.0]'
# ...Line # 46 has text content 'Vincentown, NJ' within bounding box '[55.0, 799.0], [163.0, 798.0], [163.0, 815.0], [55.0, 815.0]'
# ...Line # 47 has text content 'ETD' within bounding box '[525.0, 694.0], [557.0, 694.0], [557.0, 709.0], [526.0, 709.0]'
# ...Line # 48 has text content '09-Dec-2018' within bounding box '[524.0, 712.0], [614.0, 711.0], [614.0, 728.0], [524.0, 728.0]'
# ...Line # 49 has text content '19:00' within bounding box '[526.0, 729.0], [565.0, 730.0], [565.0, 744.0], [526.0, 744.0]'
# ...Line # 50 has text content 'tone late spoken' within bounding box '[368.0, 765.0], [480.0, 766.0], [480.0, 782.0], [368.0, 782.0]'
# ...Line # 51 has text content '12-Dec-2018' within bounding box '[525.0, 765.0], [614.0, 765.0], [614.0, 781.0], [525.0, 780.0]'
# ...Line # 52 has text content '10:00' within bounding box '[527.0, 783.0], [565.0, 782.0], [565.0, 797.0], [527.0, 797.0]'
# ...Line # 53 has text content 'Deadline' within bounding box '[55.0, 849.0], [119.0, 849.0], [119.0, 864.0], [55.0, 864.0]'
# ...Line # 54 has text content 'Table' within bounding box '[55.0, 867.0], [95.0, 867.0], [95.0, 881.0], [55.0, 881.0]'
# ...Line # 55 has text content 'Harleysville' within bounding box '[251.0, 866.0], [329.0, 867.0], [329.0, 883.0], [251.0, 882.0]'
# ...Line # 56 has text content '(PA)' within bounding box '[250.0, 884.0], [283.0, 884.0], [283.0, 900.0], [250.0, 900.0]'
# ...Line # 57 has text content 'Flight' within bounding box '[55.0, 903.0], [94.0, 903.0], [95.0, 919.0], [55.0, 919.0]'
# ...Line # 58 has text content 'Harleysville' within bounding box '[251.0, 902.0], [330.0, 902.0], [330.0, 919.0], [251.0, 918.0]'
# ...Line # 59 has text content '08-Dec-2019' within bounding box '[447.0, 902.0], [535.0, 902.0], [535.0, 918.0], [447.0, 918.0]'
# ...Line # 60 has text content '13:00' within bounding box '[448.0, 920.0], [486.0, 919.0], [486.0, 935.0], [448.0, 934.0]'
# ...Line # 61 has text content 'Round' within bounding box '[55.0, 938.0], [101.0, 938.0], [101.0, 953.0], [55.0, 952.0]'
# ...Line # 62 has text content '09-Dec-2019' within bounding box '[446.0, 938.0], [535.0, 938.0], [535.0, 952.0], [446.0, 953.0]'
# ...Line # 63 has text content '(PA)' within bounding box '[251.0, 919.0], [284.0, 919.0], [284.0, 936.0], [251.0, 935.0]'
# ...Line # 64 has text content 'Harleysville' within bounding box '[251.0, 937.0], [330.0, 938.0], [329.0, 954.0], [251.0, 953.0]'
# ...Line # 65 has text content '(PA)' within bounding box '[252.0, 955.0], [283.0, 954.0], [283.0, 971.0], [252.0, 970.0]'
# ...Line # 66 has text content 'Accent' within bounding box '[56.0, 973.0], [104.0, 973.0], [104.0, 987.0], [56.0, 987.0]'
# ...Line # 67 has text content 'Harleysville' within bounding box '[251.0, 972.0], [329.0, 972.0], [329.0, 989.0], [251.0, 988.0]'
# ...Line # 68 has text content '10-Dec-2019' within bounding box '[448.0, 972.0], [535.0, 972.0], [535.0, 988.0], [448.0, 987.0]'
# ...Line # 69 has text content '(PA)' within bounding box '[251.0, 990.0], [283.0, 991.0], [284.0, 1006.0], [251.0, 1006.0]'
# ...Line # 70 has text content 'Monkey' within bounding box '[56.0, 1008.0], [110.0, 1010.0], [110.0, 1026.0], [55.0, 1024.0]'
# ...Line # 71 has text content 'Harleysville' within bounding box '[250.0, 1008.0], [330.0, 1009.0], [330.0, 1025.0], [250.0, 1024.0]'
# ...Line # 72 has text content '(PA)' within bounding box '[252.0, 1026.0], [283.0, 1026.0], [283.0, 1041.0], [252.0, 1041.0]'
# ...Line # 73 has text content '11-Dec-2019' within bounding box '[447.0, 1009.0], [536.0, 1009.0], [536.0, 1024.0], [447.0, 1024.0]'
# ...Line # 74 has text content 'Location' within bounding box '[251.0, 849.0], [316.0, 850.0], [316.0, 865.0], [251.0, 864.0]'
# ...Line # 75 has text content 'Harleysville' within bounding box '[250.0, 1043.0], [330.0, 1043.0], [330.0, 1060.0], [250.0, 1059.0]'
# ...Line # 76 has text content '11-Dec-2019' within bounding box '[447.0, 1043.0], [536.0, 1043.0], [536.0, 1059.0], [447.0, 1058.0]'
# ...Line # 77 has text content 'Route' within bounding box '[55.0, 1045.0], [96.0, 1045.0], [96.0, 1058.0], [55.0, 1058.0]'
# ...Line # 78 has text content '(PA)' within bounding box '[252.0, 1061.0], [281.0, 1061.0], [282.0, 1077.0], [253.0, 1076.0]'
# ...Line # 79 has text content 'Date/Time (local)' within bounding box '[447.0, 849.0], [569.0, 849.0], [569.0, 866.0], [447.0, 865.0]'
# ...Line # 80 has text content '08-Dec-2019' within bounding box '[448.0, 866.0], [536.0, 866.0], [536.0, 882.0], [448.0, 882.0]'
# ...Line # 81 has text content 'Opt. B' within bounding box '[661.0, 496.0], [710.0, 496.0], [711.0, 513.0], [662.0, 513.0]'
# ...Line # 82 has text content 'ETA' within bounding box '[681.0, 695.0], [714.0, 694.0], [714.0, 709.0], [682.0, 709.0]'
# ...Line # 83 has text content '09-Dec-2020' within bounding box '[681.0, 712.0], [769.0, 712.0], [769.0, 727.0], [681.0, 728.0]'
# ...Line # 84 has text content '11:00' within bounding box '[682.0, 729.0], [721.0, 729.0], [721.0, 744.0], [683.0, 744.0]'
# ...Line # 85 has text content '19-Dec-2020' within bounding box '[681.0, 765.0], [770.0, 765.0], [770.0, 781.0], [681.0, 781.0]'
# ...Line # 86 has text content 'Required action' within bounding box '[642.0, 849.0], [757.0, 849.0], [757.0, 866.0], [642.0, 866.0]'
# ...Line # 87 has text content 'Two more days and all his' within bounding box '[642.0, 902.0], [819.0, 901.0], [819.0, 919.0], [642.0, 920.0]'
# ...Line # 88 has text content 'problems would be solved.' within bounding box '[642.0, 920.0], [821.0, 919.0], [821.0, 936.0], [642.0, 936.0]'
# ...Line # 89 has text content 'Peanuts don't grow on' within bounding box '[642.0, 1043.0], [794.0, 1044.0], [794.0, 1061.0], [642.0, 1060.0]'
# ...Line # 90 has text content 'trees.' within bounding box '[641.0, 1061.0], [682.0, 1061.0], [683.0, 1076.0], [641.0, 1076.0]'
# ...Word '555' has a confidence of 0.38
# ...Word 'Liberty's' has a confidence of 0.977
# ...Word 'Delightful' has a confidence of 0.983
# ...Word 'Sinful' has a confidence of 0.993
# ...Word 'Bakery' has a confidence of 0.995
# ...Word '&' has a confidence of 0.972
# ...Word 'Café' has a confidence of 0.582
# ...Word '765' has a confidence of 0.996
# ...Word 'Halifax' has a confidence of 0.993
# ...Word 'St.' has a confidence of 0.993
# ...Word 'Clearwater,' has a confidence of 0.99
# ...Word 'FL' has a confidence of 0.996
# ...Word '33756' has a confidence of 0.995
# ...Word 'Our' has a confidence of 0.995
# ...Word 'reference:' has a confidence of 0.992
# ...Word '3456623' has a confidence of 0.995
# ...Word 'Your' has a confidence of 0.993
# ...Word 'reference:' has a confidence of 0.986
# ...Word '2334566' has a confidence of 0.994
# ...Word 'Received' has a confidence of 0.994
# ...Word 'from:' has a confidence of 0.994
# ...Word '8556' has a confidence of 0.993
# ...Word 'Indian' has a confidence of 0.981
# ...Word 'Summer' has a confidence of 0.995
# ...Word 'Ave.' has a confidence of 0.989
# ...Word 'New' has a confidence of 0.996
# ...Word 'Haven,' has a confidence of 0.993
# ...Word 'CT' has a confidence of 0.995
# ...Word '06511' has a confidence of 0.994
# ...Word 'Liberty' has a confidence of 0.994
# ...Word 'booking' has a confidence of 0.995
# ...Word 'contact' has a confidence of 0.995
# ...Word '40' has a confidence of 0.997
# ...Word 'River' has a confidence of 0.988
# ...Word 'Street' has a confidence of 0.991
# ...Word 'East' has a confidence of 0.992
# ...Word 'Northport,' has a confidence of 0.986
# ...Word 'NY' has a confidence of 0.981
# ...Word '11731' has a confidence of 0.993
# ...Word 'Name' has a confidence of 0.993
# ...Word 'Summer' has a confidence of 0.995
# ...Word 'River' has a confidence of 0.995
# ...Word 'Tel.' has a confidence of 0.991
# ...Word '34456632' has a confidence of 0.995
# ...Word 'E-mail' has a confidence of 0.992
# ...Word 'email6@libertydelightfulsinful.com' has a confidence of 0.902
# ...Word 'Booking' has a confidence of 0.995
# ...Word 'Confirmation' has a confidence of 0.962
# ...Word '-' has a confidence of 0.995
# ...Word 'ORIGINAL' has a confidence of 0.993
# ...Word 'Our' has a confidence of 0.994
# ...Word 'reference:' has a confidence of 0.987
# ...Word '3456623' has a confidence of 0.995
# ...Word 'Your' has a confidence of 0.99
# ...Word 'reference:' has a confidence of 0.988
# ...Word '2334566' has a confidence of 0.995
# ...Word 'BL/NO:' has a confidence of 0.983
# ...Word 'EURH234' has a confidence of 0.995
# ...Word 'Summary:' has a confidence of 0.995
# ...Word '45×72' has a confidence of 0.592
# ...Word 'Booking' has a confidence of 0.994
# ...Word 'date:' has a confidence of 0.993
# ...Word '05-Dec-2018' has a confidence of 0.982
# ...Word 'Contract' has a confidence of 0.99
# ...Word 'No:' has a confidence of 0.995
# ...Word '334566' has a confidence of 0.992
# ...Word 'Export:' has a confidence of 0.889
# ...Word 'Common' has a confidence of 0.995
# ...Word 'Export' has a confidence of 0.995
# ...Word 'empty' has a confidence of 0.994
# ...Word 'pick' has a confidence of 0.993
# ...Word 'up' has a confidence of 0.995
# ...Word 'depot(s)' has a confidence of 0.994
# ...Word '97' has a confidence of 0.995
# ...Word 'Morris' has a confidence of 0.994
# ...Word 'Lane' has a confidence of 0.989
# ...Word 'Sterling' has a confidence of 0.994
# ...Word 'Heights,' has a confidence of 0.99
# ...Word 'MI' has a confidence of 0.993
# ...Word '48310' has a confidence of 0.994
# ...Word 'From' has a confidence of 0.993
# ...Word 'To' has a confidence of 0.995
# ...Word '118' has a confidence of 0.996
# ...Word 'Queen' has a confidence of 0.995
# ...Word 'Street' has a confidence of 0.995
# ...Word 'Hoboken,' has a confidence of 0.994
# ...Word 'NJ' has a confidence of 0.995
# ...Word '07030' has a confidence of 0.994
# ...Word '52' has a confidence of 0.995
# ...Word 'West' has a confidence of 0.993
# ...Word 'Trenton' has a confidence of 0.994
# ...Word 'St.' has a confidence of 0.995
# ...Word 'Harleysville,' has a confidence of 0.98
# ...Word 'PA' has a confidence of 0.995
# ...Word '19438' has a confidence of 0.989
# ...Word '75' has a confidence of 0.983
# ...Word 'Fawn' has a confidence of 0.992
# ...Word 'Street' has a confidence of 0.995
# ...Word 'Peabody,' has a confidence of 0.994
# ...Word 'MA' has a confidence of 0.996
# ...Word '01960' has a confidence of 0.995
# ...Word 'Opt.' has a confidence of 0.973
# ...Word 'A' has a confidence of 0.995
# ...Word 'By' has a confidence of 0.987
# ...Word 'cause' has a confidence of 0.995
# ...Word 'science' has a confidence of 0.995
# ...Word 'slow' has a confidence of 0.992
# ...Word '9' has a confidence of 0.995
# ...Word 'Ketch' has a confidence of 0.993
# ...Word 'Harbour' has a confidence of 0.995
# ...Word 'Ave.' has a confidence of 0.934
# ...Word 'Vincentown,' has a confidence of 0.994
# ...Word 'NJ' has a confidence of 0.997
# ...Word 'ETD' has a confidence of 0.994
# ...Word '09-Dec-2018' has a confidence of 0.982
# ...Word '19:00' has a confidence of 0.995
# ...Word 'tone' has a confidence of 0.993
# ...Word 'late' has a confidence of 0.993
# ...Word 'spoken' has a confidence of 0.995
# ...Word '12-Dec-2018' has a confidence of 0.99
# ...Word '10:00' has a confidence of 0.995
# ...Word 'Deadline' has a confidence of 0.994
# ...Word 'Table' has a confidence of 0.995
# ...Word 'Harleysville' has a confidence of 0.987
# ...Word '(PA)' has a confidence of 0.991
# ...Word 'Flight' has a confidence of 0.99
# ...Word 'Harleysville' has a confidence of 0.983
# ...Word '08-Dec-2019' has a confidence of 0.991
# ...Word '13:00' has a confidence of 0.994
# ...Word 'Round' has a confidence of 0.995
# ...Word '09-Dec-2019' has a confidence of 0.992
# ...Word '(PA)' has a confidence of 0.991
# ...Word 'Harleysville' has a confidence of 0.983
# ...Word '(PA)' has a confidence of 0.99
# ...Word 'Accent' has a confidence of 0.974
# ...Word 'Harleysville' has a confidence of 0.992
# ...Word '10-Dec-2019' has a confidence of 0.982
# ...Word '(PA)' has a confidence of 0.992
# ...Word 'Monkey' has a confidence of 0.994
# ...Word 'Harleysville' has a confidence of 0.992
# ...Word '(PA)' has a confidence of 0.992
# ...Word '11-Dec-2019' has a confidence of 0.976
# ...Word 'Location' has a confidence of 0.995
# ...Word 'Harleysville' has a confidence of 0.991
# ...Word '11-Dec-2019' has a confidence of 0.984
# ...Word 'Route' has a confidence of 0.993
# ...Word '(PA)' has a confidence of 0.987
# ...Word 'Date/Time' has a confidence of 0.991
# ...Word '(local)' has a confidence of 0.989
# ...Word '08-Dec-2019' has a confidence of 0.988
# ...Word 'Opt.' has a confidence of 0.991
# ...Word 'B' has a confidence of 0.997
# ...Word 'ETA' has a confidence of 0.994
# ...Word '09-Dec-2020' has a confidence of 0.992
# ...Word '11:00' has a confidence of 0.994
# ...Word '19-Dec-2020' has a confidence of 0.994
# ...Word 'Required' has a confidence of 0.981
# ...Word 'action' has a confidence of 0.994
# ...Word 'Two' has a confidence of 0.996
# ...Word 'more' has a confidence of 0.993
# ...Word 'days' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.996
# ...Word 'all' has a confidence of 0.995
# ...Word 'his' has a confidence of 0.996
# ...Word 'problems' has a confidence of 0.994
# ...Word 'would' has a confidence of 0.995
# ...Word 'be' has a confidence of 0.986
# ...Word 'solved.' has a confidence of 0.991
# ...Word 'Peanuts' has a confidence of 0.994
# ...Word 'don't' has a confidence of 0.995
# ...Word 'grow' has a confidence of 0.993
# ...Word 'on' has a confidence of 0.995
# ...Word 'trees.' has a confidence of 0.991
# ----------------------------------------

# %% [markdown]
# ## W-2 양식 모델

# %%
"""
This code sample shows Prebuilt Read operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://learn.microsoft.com/azure/applied-ai-services/form-recognizer/quickstarts/get-started-v3-sdk-rest-api?view=doc-intel-3.1.0&pivots=programming-language-python
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

# -> pip install azure-ai-formrecognizer
"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
endpoint = "https://b040-document.cognitiveservices.azure.com/"
key = "9njyuOpUp5Z5pFEZmGom6Yt8lMSP4FnVSKeHm981aJnUUCfFC5VPJQQJ99ALAC4f1cMXJ3w3AAALACOGqCyV"

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

def analyze_read():
    # sample document
    #formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"
    formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/rest-api/w2.png"
    
    document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    poller = document_analysis_client.begin_analyze_document_from_url(
            "prebuilt-read", formUrl)
    result = poller.result()

    print ("Document contains content: ", result.content)
    
    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")


if __name__ == "__main__":
    analyze_read()
# Out:
# Document contains content:  Copy 2 -. To Be Filed with Employee's State,
# City, or Local Income Tax Return,
# a. Employee's Soc Sec No
# 123-45-6789
# 1 Wages, tips, other comp.
# 37160.56
# 3 Social security wages
# 37160.56
# b. Employer ID number (EIN)
# 98-7654321
# 5 Medicare wages and tips
# 37160.56
# c Employer's name, address and ZIP code
# CONTOSO LTD
# 123 MICROSOFT WAY
# REDMOND, WA 98765
# d Control Number
# 000086242
# e Employee's name, address, and ZIP code
# ANGEL BROWN
# 4567 MAIN STREET
# BUFFALO, WA 12345
# 7 Social security tips
# 302.30
# 8 Allocated tips
# 874.20
# 10 Dependent care benefits
# 9873.20
# 11 Nonqualified plans
# 653.21
# 13 Statutory employee
# :14 Other
# DISINS
# 170.85
# X Retirement plan
# Third-party sick pay
# <
# PA 87654321
# WA
# 12345678
# 15 State Employer's state ID number
# 18 Local wages, tips, etc.
# 37160.56
# OMB NO. 1545-0008
# Federal Income tax withheld
# 3894.54
# A Social security tax withheld
# 2303.95
# 6 Medicare tax withheld
# 538.83
# 12a Code See inst. for box 12
# DD
# 6939.68
# 112b Code
# F
# 5432.00
# 12c Code
# D
# 876.30
# 12d Code
# C
# 123.30
# 1135.65
# 9631.20
# 17 State income tax
# 1032.30
# 19 Local income tax
# 16 State wages, tips, etc.
# 37160.56
# 20 Locality name
# 51.00 Cmberland Vly/Mddl
# 594.54 E.Pennsboro/E.Pnns
# 37160.56
# Form W-2 Wage and Tax Statement
# 2018
# Dept. of Treasury -- IRS
# Document contains handwritten content
# Document contains handwritten content
# Document contains handwritten content
# Document contains handwritten content
# ----Analyzing Read from page #1----
# Page has width: 2391.0 and height: 2325.0, measured with unit: pixel
# ...Line # 0 has text content 'Copy 2 -. To Be Filed with Employee's State,' within bounding box '[76.0, 101.0], [836.0, 98.0], [837.0, 142.0], [76.0, 143.0]'
# ...Line # 1 has text content 'City, or Local Income Tax Return,' within bounding box '[74.0, 141.0], [653.0, 139.0], [653.0, 180.0], [74.0, 183.0]'
# ...Line # 2 has text content 'a. Employee's Soc Sec No' within bounding box '[71.0, 185.0], [514.0, 183.0], [515.0, 224.0], [71.0, 228.0]'
# ...Line # 3 has text content '123-45-6789' within bounding box '[235.0, 252.0], [536.0, 250.0], [536.0, 300.0], [235.0, 302.0]'
# ...Line # 4 has text content '1 Wages, tips, other comp.' within bounding box '[732.0, 181.0], [1195.0, 186.0], [1195.0, 228.0], [732.0, 224.0]'
# ...Line # 5 has text content '37160.56' within bounding box '[1217.0, 228.0], [1485.0, 227.0], [1486.0, 282.0], [1217.0, 285.0]'
# ...Line # 6 has text content '3 Social security wages' within bounding box '[732.0, 290.0], [1135.0, 296.0], [1134.0, 338.0], [732.0, 333.0]'
# ...Line # 7 has text content '37160.56' within bounding box '[1217.0, 334.0], [1484.0, 334.0], [1485.0, 391.0], [1217.0, 394.0]'
# ...Line # 8 has text content 'b. Employer ID number (EIN)' within bounding box '[70.0, 345.0], [573.0, 343.0], [573.0, 390.0], [70.0, 391.0]'
# ...Line # 9 has text content '98-7654321' within bounding box '[254.0, 439.0], [530.0, 439.0], [530.0, 487.0], [254.0, 487.0]'
# ...Line # 10 has text content '5 Medicare wages and tips' within bounding box '[730.0, 401.0], [1184.0, 402.0], [1184.0, 446.0], [730.0, 444.0]'
# ...Line # 11 has text content '37160.56' within bounding box '[1223.0, 446.0], [1485.0, 445.0], [1486.0, 502.0], [1223.0, 505.0]'
# ...Line # 12 has text content 'c Employer's name, address and ZIP code' within bounding box '[65.0, 513.0], [789.0, 513.0], [789.0, 554.0], [65.0, 555.0]'
# ...Line # 13 has text content 'CONTOSO LTD' within bounding box '[111.0, 563.0], [511.0, 562.0], [511.0, 613.0], [111.0, 614.0]'
# ...Line # 14 has text content '123 MICROSOFT WAY' within bounding box '[117.0, 616.0], [691.0, 616.0], [691.0, 666.0], [117.0, 667.0]'
# ...Line # 15 has text content 'REDMOND, WA 98765' within bounding box '[111.0, 669.0], [691.0, 669.0], [691.0, 724.0], [111.0, 723.0]'
# ...Line # 16 has text content 'd Control Number' within bounding box '[66.0, 794.0], [376.0, 794.0], [376.0, 836.0], [66.0, 835.0]'
# ...Line # 17 has text content '000086242' within bounding box '[69.0, 841.0], [381.0, 841.0], [381.0, 892.0], [69.0, 891.0]'
# ...Line # 18 has text content 'e Employee's name, address, and ZIP code' within bounding box '[67.0, 906.0], [811.0, 907.0], [811.0, 949.0], [67.0, 947.0]'
# ...Line # 19 has text content 'ANGEL BROWN' within bounding box '[93.0, 958.0], [510.0, 958.0], [510.0, 1009.0], [93.0, 1009.0]'
# ...Line # 20 has text content '4567 MAIN STREET' within bounding box '[92.0, 1012.0], [610.0, 1012.0], [610.0, 1063.0], [92.0, 1064.0]'
# ...Line # 21 has text content 'BUFFALO, WA 12345' within bounding box '[92.0, 1064.0], [639.0, 1064.0], [639.0, 1121.0], [92.0, 1120.0]'
# ...Line # 22 has text content '7 Social security tips' within bounding box '[64.0, 1226.0], [427.0, 1228.0], [426.0, 1270.0], [64.0, 1267.0]'
# ...Line # 23 has text content '302.30' within bounding box '[634.0, 1272.0], [800.0, 1273.0], [800.0, 1322.0], [634.0, 1321.0]'
# ...Line # 24 has text content '8 Allocated tips' within bounding box '[809.0, 1225.0], [1077.0, 1225.0], [1077.0, 1271.0], [809.0, 1271.0]'
# ...Line # 25 has text content '874.20' within bounding box '[1372.0, 1268.0], [1534.0, 1268.0], [1534.0, 1316.0], [1372.0, 1316.0]'
# ...Line # 26 has text content '10 Dependent care benefits' within bounding box '[58.0, 1336.0], [546.0, 1336.0], [546.0, 1381.0], [58.0, 1381.0]'
# ...Line # 27 has text content '9873.20' within bounding box '[600.0, 1386.0], [796.0, 1386.0], [796.0, 1437.0], [600.0, 1437.0]'
# ...Line # 28 has text content '11 Nonqualified plans' within bounding box '[813.0, 1337.0], [1184.0, 1337.0], [1184.0, 1380.0], [813.0, 1380.0]'
# ...Line # 29 has text content '653.21' within bounding box '[1378.0, 1381.0], [1540.0, 1382.0], [1539.0, 1432.0], [1378.0, 1431.0]'
# ...Line # 30 has text content '13 Statutory employee' within bounding box '[63.0, 1451.0], [463.0, 1452.0], [463.0, 1494.0], [63.0, 1492.0]'
# ...Line # 31 has text content ':14 Other' within bounding box '[662.0, 1447.0], [827.0, 1448.0], [827.0, 1490.0], [662.0, 1489.0]'
# ...Line # 32 has text content 'DISINS' within bounding box '[690.0, 1537.0], [896.0, 1537.0], [897.0, 1590.0], [690.0, 1591.0]'
# ...Line # 33 has text content '170.85' within bounding box '[992.0, 1535.0], [1184.0, 1534.0], [1184.0, 1587.0], [992.0, 1588.0]'
# ...Line # 34 has text content 'X' within bounding box '[349.0, 1612.0], [377.0, 1612.0], [377.0, 1657.0], [349.0, 1657.0]'
# ...Line # 35 has text content 'Retirement plan' within bounding box '[95.0, 1564.0], [389.0, 1564.0], [389.0, 1603.0], [95.0, 1603.0]'
# ...Line # 36 has text content 'Third-party sick pay' within bounding box '[93.0, 1675.0], [447.0, 1675.0], [447.0, 1718.0], [93.0, 1717.0]'
# ...Line # 37 has text content '<' within bounding box '[344.0, 1748.0], [345.0, 1721.0], [386.0, 1723.0], [385.0, 1750.0]'
# ...Line # 38 has text content 'PA' within bounding box '[102.0, 1799.0], [158.0, 1799.0], [159.0, 1847.0], [100.0, 1846.0]'
# ...Line # 39 has text content '87654321' within bounding box '[220.0, 1796.0], [451.0, 1796.0], [452.0, 1844.0], [220.0, 1845.0]'
# ...Line # 40 has text content 'WA' within bounding box '[77.0, 1870.0], [167.0, 1870.0], [167.0, 1918.0], [76.0, 1917.0]'
# ...Line # 41 has text content '12345678' within bounding box '[215.0, 1867.0], [451.0, 1868.0], [451.0, 1916.0], [215.0, 1916.0]'
# ...Line # 42 has text content '15 State Employer's state ID number' within bounding box '[54.0, 1919.0], [709.0, 1913.0], [710.0, 1953.0], [55.0, 1961.0]'
# ...Line # 43 has text content '18 Local wages, tips, etc.' within bounding box '[51.0, 1964.0], [499.0, 1963.0], [499.0, 2007.0], [51.0, 2008.0]'
# ...Line # 44 has text content '37160.56' within bounding box '[521.0, 2010.0], [788.0, 2006.0], [789.0, 2060.0], [521.0, 2064.0]'
# ...Line # 45 has text content 'OMB NO. 1545-0008' within bounding box '[1733.0, 114.0], [2084.0, 112.0], [2084.0, 152.0], [1734.0, 154.0]'
# ...Line # 46 has text content 'Federal Income tax withheld' within bounding box '[1498.0, 179.0], [2013.0, 179.0], [2014.0, 218.0], [1498.0, 221.0]'
# ...Line # 47 has text content '3894.54' within bounding box '[2030.0, 225.0], [2252.0, 225.0], [2252.0, 278.0], [2030.0, 277.0]'
# ...Line # 48 has text content 'A Social security tax withheld' within bounding box '[1501.0, 286.0], [2009.0, 285.0], [2009.0, 328.0], [1501.0, 330.0]'
# ...Line # 49 has text content '2303.95' within bounding box '[2029.0, 333.0], [2257.0, 333.0], [2256.0, 388.0], [2029.0, 387.0]'
# ...Line # 50 has text content '6 Medicare tax withheld' within bounding box '[1505.0, 397.0], [1911.0, 397.0], [1911.0, 437.0], [1505.0, 439.0]'
# ...Line # 51 has text content '538.83' within bounding box '[2066.0, 442.0], [2255.0, 441.0], [2255.0, 499.0], [2066.0, 500.0]'
# ...Line # 52 has text content '12a Code See inst. for box 12' within bounding box '[1553.0, 1328.0], [2074.0, 1326.0], [2074.0, 1370.0], [1553.0, 1373.0]'
# ...Line # 53 has text content 'DD' within bounding box '[1847.0, 1378.0], [1939.0, 1376.0], [1940.0, 1426.0], [1847.0, 1425.0]'
# ...Line # 54 has text content '6939.68' within bounding box '[2029.0, 1373.0], [2259.0, 1372.0], [2259.0, 1426.0], [2029.0, 1428.0]'
# ...Line # 55 has text content '112b Code' within bounding box '[1557.0, 1441.0], [1731.0, 1441.0], [1731.0, 1481.0], [1557.0, 1481.0]'
# ...Line # 56 has text content 'F' within bounding box '[1850.0, 1478.0], [1881.0, 1479.0], [1881.0, 1523.0], [1850.0, 1522.0]'
# ...Line # 57 has text content '5432.00' within bounding box '[2035.0, 1476.0], [2225.0, 1477.0], [2225.0, 1525.0], [2035.0, 1524.0]'
# ...Line # 58 has text content '12c Code' within bounding box '[1561.0, 1553.0], [1725.0, 1553.0], [1725.0, 1592.0], [1561.0, 1593.0]'
# ...Line # 59 has text content 'D' within bounding box '[1847.0, 1587.0], [1880.0, 1586.0], [1880.0, 1629.0], [1848.0, 1628.0]'
# ...Line # 60 has text content '876.30' within bounding box '[2048.0, 1585.0], [2210.0, 1584.0], [2211.0, 1633.0], [2048.0, 1634.0]'
# ...Line # 61 has text content '12d Code' within bounding box '[1564.0, 1664.0], [1730.0, 1665.0], [1730.0, 1705.0], [1564.0, 1704.0]'
# ...Line # 62 has text content 'C' within bounding box '[1838.0, 1699.0], [1879.0, 1699.0], [1880.0, 1743.0], [1837.0, 1743.0]'
# ...Line # 63 has text content '123.30' within bounding box '[2061.0, 1699.0], [2219.0, 1699.0], [2219.0, 1745.0], [2061.0, 1745.0]'
# ...Line # 64 has text content '1135.65' within bounding box '[2062.0, 1785.0], [2292.0, 1784.0], [2293.0, 1835.0], [2062.0, 1837.0]'
# ...Line # 65 has text content '9631.20' within bounding box '[1392.0, 1861.0], [1585.0, 1861.0], [1584.0, 1910.0], [1392.0, 1910.0]'
# ...Line # 66 has text content '17 State income tax' within bounding box '[1625.0, 1907.0], [1981.0, 1907.0], [1981.0, 1949.0], [1625.0, 1949.0]'
# ...Line # 67 has text content '1032.30' within bounding box '[2091.0, 1856.0], [2278.0, 1857.0], [2278.0, 1904.0], [2091.0, 1904.0]'
# ...Line # 68 has text content '19 Local income tax' within bounding box '[821.0, 1957.0], [1174.0, 1958.0], [1174.0, 1999.0], [821.0, 1998.0]'
# ...Line # 69 has text content '16 State wages, tips, etc.' within bounding box '[911.0, 1911.0], [1375.0, 1908.0], [1375.0, 1950.0], [911.0, 1952.0]'
# ...Line # 70 has text content '37160.56' within bounding box '[1318.0, 1785.0], [1588.0, 1784.0], [1588.0, 1838.0], [1318.0, 1840.0]'
# ...Line # 71 has text content '20 Locality name' within bounding box '[1568.0, 1952.0], [1873.0, 1954.0], [1873.0, 1998.0], [1568.0, 1997.0]'
# ...Line # 72 has text content '51.00 Cmberland Vly/Mddl' within bounding box '[1376.0, 2005.0], [2124.0, 2006.0], [2124.0, 2064.0], [1375.0, 2062.0]'
# ...Line # 73 has text content '594.54 E.Pennsboro/E.Pnns' within bounding box '[1340.0, 2073.0], [2126.0, 2076.0], [2126.0, 2134.0], [1340.0, 2132.0]'
# ...Line # 74 has text content '37160.56' within bounding box '[516.0, 2081.0], [788.0, 2081.0], [788.0, 2136.0], [516.0, 2137.0]'
# ...Line # 75 has text content 'Form W-2 Wage and Tax Statement' within bounding box '[45.0, 2158.0], [683.0, 2150.0], [683.0, 2197.0], [45.0, 2204.0]'
# ...Line # 76 has text content '2018' within bounding box '[1256.0, 2144.0], [1368.0, 2143.0], [1368.0, 2192.0], [1255.0, 2192.0]'
# ...Line # 77 has text content 'Dept. of Treasury -- IRS' within bounding box '[1873.0, 2147.0], [2305.0, 2145.0], [2305.0, 2189.0], [1873.0, 2191.0]'
# ...Word 'Copy' has a confidence of 0.993
# ...Word '2' has a confidence of 0.979
# ...Word '-.' has a confidence of 0.722
# ...Word 'To' has a confidence of 0.996
# ...Word 'Be' has a confidence of 0.994
# ...Word 'Filed' has a confidence of 0.895
# ...Word 'with' has a confidence of 0.994
# ...Word 'Employee's' has a confidence of 0.849
# ...Word 'State,' has a confidence of 0.916
# ...Word 'City,' has a confidence of 0.985
# ...Word 'or' has a confidence of 0.979
# ...Word 'Local' has a confidence of 0.994
# ...Word 'Income' has a confidence of 0.992
# ...Word 'Tax' has a confidence of 0.987
# ...Word 'Return,' has a confidence of 0.777
# ...Word 'a.' has a confidence of 0.983
# ...Word 'Employee's' has a confidence of 0.979
# ...Word 'Soc' has a confidence of 0.993
# ...Word 'Sec' has a confidence of 0.995
# ...Word 'No' has a confidence of 0.992
# ...Word '123-45-6789' has a confidence of 0.993
# ...Word '1' has a confidence of 0.588
# ...Word 'Wages,' has a confidence of 0.988
# ...Word 'tips,' has a confidence of 0.625
# ...Word 'other' has a confidence of 0.992
# ...Word 'comp.' has a confidence of 0.992
# ...Word '37160.56' has a confidence of 0.995
# ...Word '3' has a confidence of 0.992
# ...Word 'Social' has a confidence of 0.995
# ...Word 'security' has a confidence of 0.977
# ...Word 'wages' has a confidence of 0.958
# ...Word '37160.56' has a confidence of 0.995
# ...Word 'b.' has a confidence of 0.902
# ...Word 'Employer' has a confidence of 0.962
# ...Word 'ID' has a confidence of 0.986
# ...Word 'number' has a confidence of 0.983
# ...Word '(EIN)' has a confidence of 0.882
# ...Word '98-7654321' has a confidence of 0.993
# ...Word '5' has a confidence of 0.99
# ...Word 'Medicare' has a confidence of 0.991
# ...Word 'wages' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.995
# ...Word 'tips' has a confidence of 0.983
# ...Word '37160.56' has a confidence of 0.995
# ...Word 'c' has a confidence of 0.842
# ...Word 'Employer's' has a confidence of 0.973
# ...Word 'name,' has a confidence of 0.961
# ...Word 'address' has a confidence of 0.98
# ...Word 'and' has a confidence of 0.961
# ...Word 'ZIP' has a confidence of 0.76
# ...Word 'code' has a confidence of 0.989
# ...Word 'CONTOSO' has a confidence of 0.995
# ...Word 'LTD' has a confidence of 0.996
# ...Word '123' has a confidence of 0.993
# ...Word 'MICROSOFT' has a confidence of 0.993
# ...Word 'WAY' has a confidence of 0.995
# ...Word 'REDMOND,' has a confidence of 0.993
# ...Word 'WA' has a confidence of 0.995
# ...Word '98765' has a confidence of 0.994
# ...Word 'd' has a confidence of 0.962
# ...Word 'Control' has a confidence of 0.994
# ...Word 'Number' has a confidence of 0.993
# ...Word '000086242' has a confidence of 0.995
# ...Word 'e' has a confidence of 0.907
# ...Word 'Employee's' has a confidence of 0.961
# ...Word 'name,' has a confidence of 0.993
# ...Word 'address,' has a confidence of 0.986
# ...Word 'and' has a confidence of 0.995
# ...Word 'ZIP' has a confidence of 0.953
# ...Word 'code' has a confidence of 0.992
# ...Word 'ANGEL' has a confidence of 0.993
# ...Word 'BROWN' has a confidence of 0.993
# ...Word '4567' has a confidence of 0.993
# ...Word 'MAIN' has a confidence of 0.991
# ...Word 'STREET' has a confidence of 0.984
# ...Word 'BUFFALO,' has a confidence of 0.994
# ...Word 'WA' has a confidence of 0.995
# ...Word '12345' has a confidence of 0.995
# ...Word '7' has a confidence of 0.995
# ...Word 'Social' has a confidence of 0.993
# ...Word 'security' has a confidence of 0.993
# ...Word 'tips' has a confidence of 0.99
# ...Word '302.30' has a confidence of 0.993
# ...Word '8' has a confidence of 0.74
# ...Word 'Allocated' has a confidence of 0.872
# ...Word 'tips' has a confidence of 0.99
# ...Word '874.20' has a confidence of 0.993
# ...Word '10' has a confidence of 0.995
# ...Word 'Dependent' has a confidence of 0.992
# ...Word 'care' has a confidence of 0.992
# ...Word 'benefits' has a confidence of 0.992
# ...Word '9873.20' has a confidence of 0.995
# ...Word '11' has a confidence of 0.995
# ...Word 'Nonqualified' has a confidence of 0.983
# ...Word 'plans' has a confidence of 0.993
# ...Word '653.21' has a confidence of 0.995
# ...Word '13' has a confidence of 0.995
# ...Word 'Statutory' has a confidence of 0.993
# ...Word 'employee' has a confidence of 0.988
# ...Word ':14' has a confidence of 0.573
# ...Word 'Other' has a confidence of 0.995
# ...Word 'DISINS' has a confidence of 0.995
# ...Word '170.85' has a confidence of 0.995
# ...Word 'X' has a confidence of 0.903
# ...Word 'Retirement' has a confidence of 0.985
# ...Word 'plan' has a confidence of 0.961
# ...Word 'Third-party' has a confidence of 0.993
# ...Word 'sick' has a confidence of 0.99
# ...Word 'pay' has a confidence of 0.995
# ...Word '<' has a confidence of 0.569
# ...Word 'PA' has a confidence of 0.994
# ...Word '87654321' has a confidence of 0.994
# ...Word 'WA' has a confidence of 0.995
# ...Word '12345678' has a confidence of 0.993
# ...Word '15' has a confidence of 0.995
# ...Word 'State' has a confidence of 0.995
# ...Word 'Employer's' has a confidence of 0.891
# ...Word 'state' has a confidence of 0.961
# ...Word 'ID' has a confidence of 0.973
# ...Word 'number' has a confidence of 0.961
# ...Word '18' has a confidence of 0.995
# ...Word 'Local' has a confidence of 0.974
# ...Word 'wages,' has a confidence of 0.994
# ...Word 'tips,' has a confidence of 0.994
# ...Word 'etc.' has a confidence of 0.985
# ...Word '37160.56' has a confidence of 0.995
# ...Word 'OMB' has a confidence of 0.979
# ...Word 'NO.' has a confidence of 0.979
# ...Word '1545-0008' has a confidence of 0.992
# ...Word 'Federal' has a confidence of 0.653
# ...Word 'Income' has a confidence of 0.893
# ...Word 'tax' has a confidence of 0.994
# ...Word 'withheld' has a confidence of 0.892
# ...Word '3894.54' has a confidence of 0.995
# ...Word 'A' has a confidence of 0.38
# ...Word 'Social' has a confidence of 0.9
# ...Word 'security' has a confidence of 0.869
# ...Word 'tax' has a confidence of 0.339
# ...Word 'withheld' has a confidence of 0.964
# ...Word '2303.95' has a confidence of 0.975
# ...Word '6' has a confidence of 0.641
# ...Word 'Medicare' has a confidence of 0.92
# ...Word 'tax' has a confidence of 0.93
# ...Word 'withheld' has a confidence of 0.993
# ...Word '538.83' has a confidence of 0.993
# ...Word '12a' has a confidence of 0.982
# ...Word 'Code' has a confidence of 0.991
# ...Word 'See' has a confidence of 0.995
# ...Word 'inst.' has a confidence of 0.993
# ...Word 'for' has a confidence of 0.992
# ...Word 'box' has a confidence of 0.995
# ...Word '12' has a confidence of 0.995
# ...Word 'DD' has a confidence of 0.995
# ...Word '6939.68' has a confidence of 0.995
# ...Word '112b' has a confidence of 0.716
# ...Word 'Code' has a confidence of 0.992
# ...Word 'F' has a confidence of 0.995
# ...Word '5432.00' has a confidence of 0.994
# ...Word '12c' has a confidence of 0.781
# ...Word 'Code' has a confidence of 0.992
# ...Word 'D' has a confidence of 0.995
# ...Word '876.30' has a confidence of 0.995
# ...Word '12d' has a confidence of 0.961
# ...Word 'Code' has a confidence of 0.993
# ...Word 'C' has a confidence of 0.995
# ...Word '123.30' has a confidence of 0.995
# ...Word '1135.65' has a confidence of 0.994
# ...Word '9631.20' has a confidence of 0.995
# ...Word '17' has a confidence of 0.997
# ...Word 'State' has a confidence of 0.995
# ...Word 'income' has a confidence of 0.945
# ...Word 'tax' has a confidence of 0.995
# ...Word '1032.30' has a confidence of 0.993
# ...Word '19' has a confidence of 0.996
# ...Word 'Local' has a confidence of 0.99
# ...Word 'income' has a confidence of 0.883
# ...Word 'tax' has a confidence of 0.993
# ...Word '16' has a confidence of 0.98
# ...Word 'State' has a confidence of 0.995
# ...Word 'wages,' has a confidence of 0.726
# ...Word 'tips,' has a confidence of 0.991
# ...Word 'etc.' has a confidence of 0.973
# ...Word '37160.56' has a confidence of 0.995
# ...Word '20' has a confidence of 0.995
# ...Word 'Locality' has a confidence of 0.993
# ...Word 'name' has a confidence of 0.993
# ...Word '51.00' has a confidence of 0.988
# ...Word 'Cmberland' has a confidence of 0.961
# ...Word 'Vly/Mddl' has a confidence of 0.792
# ...Word '594.54' has a confidence of 0.995
# ...Word 'E.Pennsboro/E.Pnns' has a confidence of 0.962
# ...Word '37160.56' has a confidence of 0.993
# ...Word 'Form' has a confidence of 0.993
# ...Word 'W-2' has a confidence of 0.995
# ...Word 'Wage' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.995
# ...Word 'Tax' has a confidence of 0.995
# ...Word 'Statement' has a confidence of 0.962
# ...Word '2018' has a confidence of 0.993
# ...Word 'Dept.' has a confidence of 0.994
# ...Word 'of' has a confidence of 0.995
# ...Word 'Treasury' has a confidence of 0.984
# ...Word '--' has a confidence of 0.961
# ...Word 'IRS' has a confidence of 0.823
# ----------------------------------------

# %% [markdown]
# ## 청구서 모델

# %%
"""
This code sample shows Prebuilt Read operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://learn.microsoft.com/azure/applied-ai-services/form-recognizer/quickstarts/get-started-v3-sdk-rest-api?view=doc-intel-3.1.0&pivots=programming-language-python
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

# -> pip install azure-ai-formrecognizer
"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
endpoint = "https://b040-document.cognitiveservices.azure.com/"
key = "9njyuOpUp5Z5pFEZmGom6Yt8lMSP4FnVSKeHm981aJnUUCfFC5VPJQQJ99ALAC4f1cMXJ3w3AAALACOGqCyV"

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

def analyze_read():
    # sample document
    #formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"
    formUrl = "https://github.com/Azure-Samples/cognitive-services-REST-api-samples/raw/master/curl/form-recognizer/rest-api/invoice.pdf"
    
    document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    poller = document_analysis_client.begin_analyze_document_from_url(
            "prebuilt-read", formUrl)
    result = poller.result()

    print ("Document contains content: ", result.content)
    
    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")


if __name__ == "__main__":
    analyze_read()
# Out:
# Document contains content:  CONTOSO LTD.
# Contoso Headquarters 123 456th St New York, NY, 10001
# Microsoft Corp 123 Other St, Redmond WA, 98052
# BILL TO:
# Microsoft Finance
# 123 Bill St,
# Redmond WA, 98052
# INVOICE
# INVOICE: INV-100 INVOICE DATE: 11/15/2019 DUE DATE: 12/15/2019 CUSTOMER NAME: MICROSOFT CORPORATION SERVICE PERIOD: 10/14/2019 - 11/14/2019 CUSTOMER ID: CID-12345
# SHIP TO:
# Microsoft Delivery
# 123 Ship St,
# Redmond WA, 98052
# SALESPERSON
# P.O. NUMBER
# PO-3333
# SERVICE ADDRESS: Microsoft Services 123 Service St, Redmond WA, 98052
# REQUISITIONER
# DATE
# ITEM CODE
# DESCRIPTION
# 3/4/2021 A123
# 3/5/2021 B456
# Consulting Services 2
# Document Fee 3
# 3/6/2021 C789
# Printing Fee
# SHIPPED VIA
# F.O.B. POINT
# TERMS
# QTY
# UM
# PRICE
# TAX $30.00
# hours
# $6.00
# $3.00
# $10.00
# $1.00
# $1.00
# AMOUNT
# $60.00
# $30.00
# $10.00
# 10
# pages
# SUBTOTAL
# $100.00
# SALES TAX
# $10.00
# TOTAL
# $110.00
# PREVIOUS UNPAID BALANCE
# $500.00
# AMOUNT DUE
# $610.00
# THANK YOU FOR YOUR BUSINESS!
# REMIT TO:
# Contoso Billing
# 123 Remit St
# New York, NY, 10001
# ----Analyzing Read from page #1----
# Page has width: 8.5 and height: 11.0, measured with unit: inch
# ...Line # 0 has text content 'CONTOSO LTD.' within bounding box '[0.5778, 0.6493], [2.3303, 0.6493], [2.3303, 0.8976], [0.5778, 0.8928]'
# ...Line # 1 has text content 'Contoso Headquarters' within bounding box '[0.5635, 1.3989], [2.1154, 1.3989], [2.1154, 1.5707], [0.5635, 1.5707]'
# ...Line # 2 has text content '123 456th St' within bounding box '[0.5778, 1.6042], [1.3992, 1.6042], [1.3992, 1.7665], [0.5778, 1.7665]'
# ...Line # 3 has text content 'New York, NY, 10001' within bounding box '[0.5635, 1.8047], [1.9913, 1.8047], [1.9913, 1.9766], [0.5635, 1.9766]'
# ...Line # 4 has text content 'Microsoft Corp' within bounding box '[0.573, 2.6306], [1.6045, 2.6306], [1.5997, 2.7977], [0.573, 2.7882]'
# ...Line # 5 has text content '123 Other St,' within bounding box '[0.5778, 2.8264], [1.4803, 2.8264], [1.4756, 2.9935], [0.5778, 2.9887]'
# ...Line # 6 has text content 'Redmond WA, 98052' within bounding box '[0.5683, 3.0317], [2.0152, 3.0221], [2.0152, 3.194], [0.5683, 3.2036]'
# ...Line # 7 has text content 'BILL TO:' within bounding box '[0.5683, 3.533], [1.1126, 3.533], [1.1126, 3.6762], [0.5683, 3.6762]'
# ...Line # 8 has text content 'Microsoft Finance' within bounding box '[0.5683, 3.7478], [1.8051, 3.7478], [1.8051, 3.9006], [0.5683, 3.9006]'
# ...Line # 9 has text content '123 Bill St,' within bounding box '[0.5826, 3.9531], [1.2893, 3.9531], [1.2893, 4.1107], [0.5826, 4.1107]'
# ...Line # 10 has text content 'Redmond WA, 98052' within bounding box '[0.5635, 4.1441], [2.0152, 4.1441], [2.0152, 4.3112], [0.5635, 4.3112]'
# ...Line # 11 has text content 'INVOICE' within bounding box '[7.0531, 0.5729], [8.0129, 0.5634], [8.0129, 0.7782], [7.0531, 0.7878]'
# ...Line # 12 has text content 'INVOICE: INV-100' within bounding box '[6.843, 1.3893], [8.0129, 1.3893], [8.0129, 1.5421], [6.843, 1.5373]'
# ...Line # 13 has text content 'INVOICE DATE: 11/15/2019' within bounding box '[6.2079, 1.5946], [8.0034, 1.5946], [8.0034, 1.7522], [6.2079, 1.7474]'
# ...Line # 14 has text content 'DUE DATE: 12/15/2019' within bounding box '[6.4705, 1.7999], [7.9986, 1.7999], [7.9986, 1.9479], [6.4705, 1.9527]'
# ...Line # 15 has text content 'CUSTOMER NAME: MICROSOFT CORPORATION' within bounding box '[4.9329, 2.0052], [7.9986, 2.0052], [7.9986, 2.1628], [4.9329, 2.1675]'
# ...Line # 16 has text content 'SERVICE PERIOD: 10/14/2019 - 11/14/2019' within bounding box '[5.1478, 2.2105], [8.0034, 2.2105], [8.0034, 2.3681], [5.1478, 2.3633]'
# ...Line # 17 has text content 'CUSTOMER ID: CID-12345' within bounding box '[6.3081, 2.4206], [8.0081, 2.4206], [8.0081, 2.5686], [6.3081, 2.5734]'
# ...Line # 18 has text content 'SHIP TO:' within bounding box '[3.314, 3.533], [3.911, 3.533], [3.911, 3.681], [3.314, 3.6762]'
# ...Line # 19 has text content 'Microsoft Delivery' within bounding box '[3.3093, 3.7383], [4.589, 3.7478], [4.589, 3.9197], [3.3093, 3.9054]'
# ...Line # 20 has text content '123 Ship St,' within bounding box '[3.3284, 3.9531], [4.1163, 3.9531], [4.1163, 4.1202], [3.3284, 4.1155]'
# ...Line # 21 has text content 'Redmond WA, 98052' within bounding box '[3.314, 4.1393], [4.7657, 4.1393], [4.7657, 4.3112], [3.314, 4.3064]'
# ...Line # 22 has text content 'SALESPERSON' within bounding box '[0.6781, 4.6263], [1.6236, 4.6263], [1.6236, 4.7695], [0.6781, 4.7743]'
# ...Line # 23 has text content 'P.O. NUMBER' within bounding box '[2.0963, 4.6263], [3.0275, 4.6263], [3.0275, 4.7695], [2.0963, 4.7648]'
# ...Line # 24 has text content 'PO-3333' within bounding box '[1.8815, 4.9032], [2.4831, 4.9032], [2.4831, 5.056], [1.8815, 5.056]'
# ...Line # 25 has text content 'SERVICE ADDRESS:' within bounding box '[6.1792, 3.5282], [7.4399, 3.5234], [7.4399, 3.6858], [6.1792, 3.6858]'
# ...Line # 26 has text content 'Microsoft Services' within bounding box '[6.1935, 3.7431], [7.4494, 3.7478], [7.4494, 3.9006], [6.1935, 3.9006]'
# ...Line # 27 has text content '123 Service St,' within bounding box '[6.2079, 3.9484], [7.1963, 3.9531], [7.1916, 4.1107], [6.2079, 4.1107]'
# ...Line # 28 has text content 'Redmond WA, 98052' within bounding box '[6.1935, 4.1441], [7.6452, 4.1441], [7.6452, 4.3112], [6.1935, 4.3112]'
# ...Line # 29 has text content 'REQUISITIONER' within bounding box '[3.4716, 4.6215], [4.5317, 4.6215], [4.5317, 4.7743], [3.4716, 4.7743]'
# ...Line # 30 has text content 'DATE' within bounding box '[0.7258, 5.4045], [1.084, 5.3997], [1.084, 5.5286], [0.7258, 5.5334]'
# ...Line # 31 has text content 'ITEM CODE' within bounding box '[1.3896, 5.395], [2.1537, 5.395], [2.1537, 5.5334], [1.3896, 5.5334]'
# ...Line # 32 has text content 'DESCRIPTION' within bounding box '[2.827, 5.3997], [3.7247, 5.3997], [3.7247, 5.5334], [2.827, 5.5334]'
# ...Line # 33 has text content '3/4/2021' within bounding box '[0.573, 5.6623], [1.2225, 5.6623], [1.2225, 5.8342], [0.573, 5.8342]'
# ...Line # 34 has text content 'A123' within bounding box '[1.5854, 5.6719], [1.9531, 5.6719], [1.9531, 5.8151], [1.5902, 5.8103]'
# ...Line # 35 has text content '3/5/2021' within bounding box '[0.573, 5.9583], [1.2272, 5.9583], [1.2272, 6.1207], [0.573, 6.1254]'
# ...Line # 36 has text content 'B456' within bounding box '[1.5902, 5.9727], [1.9531, 5.9727], [1.9531, 6.1063], [1.5949, 6.1111]'
# ...Line # 37 has text content 'Consulting Services' within bounding box '[2.316, 5.6719], [3.634, 5.6719], [3.634, 5.8294], [2.316, 5.8342]'
# ...Line # 38 has text content '2' within bounding box '[4.5843, 5.6767], [4.6654, 5.6767], [4.6654, 5.8056], [4.5843, 5.8008]'
# ...Line # 39 has text content 'Document Fee' within bounding box '[2.3208, 5.9679], [3.3188, 5.9679], [3.3188, 6.1159], [2.3208, 6.1207]'
# ...Line # 40 has text content '3' within bounding box '[4.5843, 5.9774], [4.6654, 5.9774], [4.675, 6.1016], [4.589, 6.1016]'
# ...Line # 41 has text content '3/6/2021' within bounding box '[0.573, 6.2639], [1.2177, 6.2591], [1.2177, 6.4214], [0.573, 6.4214]'
# ...Line # 42 has text content 'C789' within bounding box '[1.5854, 6.2687], [1.9483, 6.2687], [1.9483, 6.4167], [1.5902, 6.4119]'
# ...Line # 43 has text content 'Printing Fee' within bounding box '[2.316, 6.2687], [3.1517, 6.2687], [3.1517, 6.4358], [2.316, 6.4358]'
# ...Line # 44 has text content 'SHIPPED VIA' within bounding box '[4.7801, 4.6311], [5.6348, 4.6311], [5.6348, 4.7648], [4.7848, 4.7648]'
# ...Line # 45 has text content 'F.O.B. POINT' within bounding box '[5.8449, 4.6263], [6.7093, 4.6263], [6.7093, 4.7695], [5.8449, 4.7695]'
# ...Line # 46 has text content 'TERMS' within bounding box '[7.1581, 4.6263], [7.6309, 4.6263], [7.6309, 4.7648], [7.1581, 4.7648]'
# ...Line # 47 has text content 'QTY' within bounding box '[4.3789, 5.4045], [4.6654, 5.4045], [4.6654, 5.5382], [4.3789, 5.5382]'
# ...Line # 48 has text content 'UM' within bounding box '[5.0284, 5.3997], [5.2719, 5.4045], [5.2719, 5.5334], [5.0284, 5.5334]'
# ...Line # 49 has text content 'PRICE' within bounding box '[5.8306, 5.3997], [6.227, 5.3997], [6.227, 5.5286], [5.8306, 5.5286]'
# ...Line # 50 has text content 'TAX' within bounding box '[6.6997, 5.4045], [6.9815, 5.3997], [6.9815, 5.5286], [6.7045, 5.5286]'
# ...Line # 51 has text content '$30.00' within bounding box '[5.9404, 5.6623], [6.418, 5.6623], [6.4228, 5.8247], [5.9357, 5.8294]'
# ...Line # 52 has text content 'hours' within bounding box '[4.8183, 5.6767], [5.2146, 5.6767], [5.2194, 5.8151], [4.823, 5.8151]'
# ...Line # 53 has text content '$6.00' within bounding box '[6.6902, 5.6671], [7.0865, 5.6671], [7.0913, 5.8199], [6.6949, 5.8294]'
# ...Line # 54 has text content '$3.00' within bounding box '[6.6949, 5.9583], [7.0913, 5.9583], [7.0961, 6.1207], [6.6949, 6.1207]'
# ...Line # 55 has text content '$10.00' within bounding box '[5.9404, 5.9631], [6.4275, 5.9631], [6.4275, 6.1159], [5.9404, 6.1207]'
# ...Line # 56 has text content '$1.00' within bounding box '[6.0312, 6.2591], [6.4228, 6.2543], [6.4275, 6.4167], [6.0264, 6.4214]'
# ...Line # 57 has text content '$1.00' within bounding box '[6.6902, 6.2687], [7.0865, 6.2639], [7.0865, 6.4167], [6.6949, 6.4167]'
# ...Line # 58 has text content 'AMOUNT' within bounding box '[7.2632, 5.395], [7.9174, 5.395], [7.9174, 5.5382], [7.2632, 5.5382]'
# ...Line # 59 has text content '$60.00' within bounding box '[7.4447, 5.6671], [7.9222, 5.6671], [7.9222, 5.8294], [7.4447, 5.8294]'
# ...Line # 60 has text content '$30.00' within bounding box '[7.4447, 5.9631], [7.9222, 5.9583], [7.9222, 6.1159], [7.4494, 6.1207]'
# ...Line # 61 has text content '$10.00' within bounding box '[7.4351, 6.2639], [7.927, 6.2591], [7.927, 6.4167], [7.4351, 6.4214]'
# ...Line # 62 has text content '10' within bounding box '[4.4983, 6.2734], [4.6702, 6.2734], [4.675, 6.4071], [4.5079, 6.4119]'
# ...Line # 63 has text content 'pages' within bounding box '[4.8087, 6.283], [5.2337, 6.283], [5.2337, 6.4453], [4.8087, 6.4453]'
# ...Line # 64 has text content 'SUBTOTAL' within bounding box '[6.0073, 6.8845], [6.7427, 6.8845], [6.7427, 7.0421], [6.0073, 7.0373]'
# ...Line # 65 has text content '$100.00' within bounding box '[7.3587, 6.8511], [7.9317, 6.8511], [7.9317, 7.0135], [7.3587, 7.0135]'
# ...Line # 66 has text content 'SALES TAX' within bounding box '[6.0169, 7.1662], [6.7427, 7.1662], [6.7427, 7.3381], [6.0169, 7.3333]'
# ...Line # 67 has text content '$10.00' within bounding box '[7.4494, 7.1567], [7.927, 7.1519], [7.9317, 7.3142], [7.4494, 7.319]'
# ...Line # 68 has text content 'TOTAL' within bounding box '[6.2795, 7.4861], [6.7331, 7.4861], [6.7331, 7.6389], [6.2795, 7.6293]'
# ...Line # 69 has text content '$110.00' within bounding box '[7.3683, 7.4575], [7.9317, 7.4479], [7.9317, 7.615], [7.3683, 7.6246]'
# ...Line # 70 has text content 'PREVIOUS UNPAID BALANCE' within bounding box '[4.7801, 7.7726], [6.7331, 7.7726], [6.7331, 7.9349], [4.7801, 7.9349]'
# ...Line # 71 has text content '$500.00' within bounding box '[7.3587, 7.7487], [7.9413, 7.7487], [7.9413, 7.911], [7.3587, 7.911]'
# ...Line # 72 has text content 'AMOUNT DUE' within bounding box '[5.7494, 8.0686], [6.7379, 8.0686], [6.7379, 8.2309], [5.7494, 8.2261]'
# ...Line # 73 has text content '$610.00' within bounding box '[7.3587, 8.0399], [7.9413, 8.0399], [7.9413, 8.2118], [7.3587, 8.2118]'
# ...Line # 74 has text content 'THANK YOU FOR YOUR BUSINESS!' within bounding box '[3.1087, 8.5078], [5.377, 8.5078], [5.377, 8.6701], [3.1087, 8.6701]'
# ...Line # 75 has text content 'REMIT TO:' within bounding box '[0.5683, 9.138], [1.275, 9.1332], [1.275, 9.2717], [0.5683, 9.2765]'
# ...Line # 76 has text content 'Contoso Billing' within bounding box '[0.5683, 9.3481], [1.5902, 9.3481], [1.5902, 9.5152], [0.5683, 9.5056]'
# ...Line # 77 has text content '123 Remit St' within bounding box '[0.5778, 9.5486], [1.4469, 9.5486], [1.4469, 9.6966], [0.5778, 9.6966]'
# ...Line # 78 has text content 'New York, NY, 10001' within bounding box '[0.5635, 9.7491], [1.9961, 9.7444], [1.9961, 9.921], [0.5635, 9.9258]'
# ...Word 'CONTOSO' has a confidence of 0.995
# ...Word 'LTD.' has a confidence of 0.991
# ...Word 'Contoso' has a confidence of 0.994
# ...Word 'Headquarters' has a confidence of 0.992
# ...Word '123' has a confidence of 0.997
# ...Word '456th' has a confidence of 0.976
# ...Word 'St' has a confidence of 0.995
# ...Word 'New' has a confidence of 0.996
# ...Word 'York,' has a confidence of 0.995
# ...Word 'NY,' has a confidence of 0.985
# ...Word '10001' has a confidence of 0.994
# ...Word 'Microsoft' has a confidence of 0.993
# ...Word 'Corp' has a confidence of 0.993
# ...Word '123' has a confidence of 0.994
# ...Word 'Other' has a confidence of 0.995
# ...Word 'St,' has a confidence of 0.993
# ...Word 'Redmond' has a confidence of 0.995
# ...Word 'WA,' has a confidence of 0.995
# ...Word '98052' has a confidence of 0.995
# ...Word 'BILL' has a confidence of 0.979
# ...Word 'TO:' has a confidence of 0.995
# ...Word 'Microsoft' has a confidence of 0.994
# ...Word 'Finance' has a confidence of 0.995
# ...Word '123' has a confidence of 0.996
# ...Word 'Bill' has a confidence of 0.993
# ...Word 'St,' has a confidence of 0.995
# ...Word 'Redmond' has a confidence of 0.995
# ...Word 'WA,' has a confidence of 0.995
# ...Word '98052' has a confidence of 0.995
# ...Word 'INVOICE' has a confidence of 0.995
# ...Word 'INVOICE:' has a confidence of 0.974
# ...Word 'INV-100' has a confidence of 0.994
# ...Word 'INVOICE' has a confidence of 0.995
# ...Word 'DATE:' has a confidence of 0.993
# ...Word '11/15/2019' has a confidence of 0.988
# ...Word 'DUE' has a confidence of 0.996
# ...Word 'DATE:' has a confidence of 0.993
# ...Word '12/15/2019' has a confidence of 0.991
# ...Word 'CUSTOMER' has a confidence of 0.995
# ...Word 'NAME:' has a confidence of 0.993
# ...Word 'MICROSOFT' has a confidence of 0.993
# ...Word 'CORPORATION' has a confidence of 0.993
# ...Word 'SERVICE' has a confidence of 0.995
# ...Word 'PERIOD:' has a confidence of 0.993
# ...Word '10/14/2019' has a confidence of 0.994
# ...Word '-' has a confidence of 0.995
# ...Word '11/14/2019' has a confidence of 0.961
# ...Word 'CUSTOMER' has a confidence of 0.995
# ...Word 'ID:' has a confidence of 0.995
# ...Word 'CID-12345' has a confidence of 0.992
# ...Word 'SHIP' has a confidence of 0.986
# ...Word 'TO:' has a confidence of 0.995
# ...Word 'Microsoft' has a confidence of 0.993
# ...Word 'Delivery' has a confidence of 0.995
# ...Word '123' has a confidence of 0.997
# ...Word 'Ship' has a confidence of 0.993
# ...Word 'St,' has a confidence of 0.995
# ...Word 'Redmond' has a confidence of 0.995
# ...Word 'WA,' has a confidence of 0.995
# ...Word '98052' has a confidence of 0.995
# ...Word 'SALESPERSON' has a confidence of 0.993
# ...Word 'P.O.' has a confidence of 0.992
# ...Word 'NUMBER' has a confidence of 0.995
# ...Word 'PO-3333' has a confidence of 0.961
# ...Word 'SERVICE' has a confidence of 0.961
# ...Word 'ADDRESS:' has a confidence of 0.989
# ...Word 'Microsoft' has a confidence of 0.989
# ...Word 'Services' has a confidence of 0.994
# ...Word '123' has a confidence of 0.997
# ...Word 'Service' has a confidence of 0.995
# ...Word 'St,' has a confidence of 0.995
# ...Word 'Redmond' has a confidence of 0.995
# ...Word 'WA,' has a confidence of 0.995
# ...Word '98052' has a confidence of 0.995
# ...Word 'REQUISITIONER' has a confidence of 0.993
# ...Word 'DATE' has a confidence of 0.993
# ...Word 'ITEM' has a confidence of 0.991
# ...Word 'CODE' has a confidence of 0.982
# ...Word 'DESCRIPTION' has a confidence of 0.993
# ...Word '3/4/2021' has a confidence of 0.995
# ...Word 'A123' has a confidence of 0.993
# ...Word '3/5/2021' has a confidence of 0.995
# ...Word 'B456' has a confidence of 0.993
# ...Word 'Consulting' has a confidence of 0.979
# ...Word 'Services' has a confidence of 0.994
# ...Word '2' has a confidence of 0.996
# ...Word 'Document' has a confidence of 0.992
# ...Word 'Fee' has a confidence of 0.996
# ...Word '3' has a confidence of 0.995
# ...Word '3/6/2021' has a confidence of 0.99
# ...Word 'C789' has a confidence of 0.992
# ...Word 'Printing' has a confidence of 0.994
# ...Word 'Fee' has a confidence of 0.994
# ...Word 'SHIPPED' has a confidence of 0.995
# ...Word 'VIA' has a confidence of 0.996
# ...Word 'F.O.B.' has a confidence of 0.993
# ...Word 'POINT' has a confidence of 0.993
# ...Word 'TERMS' has a confidence of 0.994
# ...Word 'QTY' has a confidence of 0.995
# ...Word 'UM' has a confidence of 0.995
# ...Word 'PRICE' has a confidence of 0.995
# ...Word 'TAX' has a confidence of 0.995
# ...Word '$30.00' has a confidence of 0.995
# ...Word 'hours' has a confidence of 0.994
# ...Word '$6.00' has a confidence of 0.995
# ...Word '$3.00' has a confidence of 0.995
# ...Word '$10.00' has a confidence of 0.995
# ...Word '$1.00' has a confidence of 0.993
# ...Word '$1.00' has a confidence of 0.995
# ...Word 'AMOUNT' has a confidence of 0.995
# ...Word '$60.00' has a confidence of 0.993
# ...Word '$30.00' has a confidence of 0.994
# ...Word '$10.00' has a confidence of 0.995
# ...Word '10' has a confidence of 0.998
# ...Word 'pages' has a confidence of 0.991
# ...Word 'SUBTOTAL' has a confidence of 0.995
# ...Word '$100.00' has a confidence of 0.993
# ...Word 'SALES' has a confidence of 0.994
# ...Word 'TAX' has a confidence of 0.996
# ...Word '$10.00' has a confidence of 0.995
# ...Word 'TOTAL' has a confidence of 0.995
# ...Word '$110.00' has a confidence of 0.98
# ...Word 'PREVIOUS' has a confidence of 0.981
# ...Word 'UNPAID' has a confidence of 0.994
# ...Word 'BALANCE' has a confidence of 0.992
# ...Word '$500.00' has a confidence of 0.995
# ...Word 'AMOUNT' has a confidence of 0.995
# ...Word 'DUE' has a confidence of 0.996
# ...Word '$610.00' has a confidence of 0.972
# ...Word 'THANK' has a confidence of 0.995
# ...Word 'YOU' has a confidence of 0.997
# ...Word 'FOR' has a confidence of 0.994
# ...Word 'YOUR' has a confidence of 0.993
# ...Word 'BUSINESS!' has a confidence of 0.97
# ...Word 'REMIT' has a confidence of 0.993
# ...Word 'TO:' has a confidence of 0.995
# ...Word 'Contoso' has a confidence of 0.995
# ...Word 'Billing' has a confidence of 0.994
# ...Word '123' has a confidence of 0.996
# ...Word 'Remit' has a confidence of 0.995
# ...Word 'St' has a confidence of 0.997
# ...Word 'New' has a confidence of 0.997
# ...Word 'York,' has a confidence of 0.995
# ...Word 'NY,' has a confidence of 0.993
# ...Word '10001' has a confidence of 0.995
# ----------------------------------------

# %% [markdown]
# ## 영수증 모델

# %%
"""
This code sample shows Prebuilt Read operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://learn.microsoft.com/azure/applied-ai-services/form-recognizer/quickstarts/get-started-v3-sdk-rest-api?view=doc-intel-3.1.0&pivots=programming-language-python
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

# -> pip install azure-ai-formrecognizer
"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
endpoint = "https://b040-document.cognitiveservices.azure.com/"
key = "9njyuOpUp5Z5pFEZmGom6Yt8lMSP4FnVSKeHm981aJnUUCfFC5VPJQQJ99ALAC4f1cMXJ3w3AAALACOGqCyV"

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

def analyze_read():
    # sample document
    #formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"
    formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/rest-api/receipt.png"
    
    document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    poller = document_analysis_client.begin_analyze_document_from_url(
            "prebuilt-read", formUrl)
    result = poller.result()

    print ("Document contains content: ", result.content)
    
    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")


if __name__ == "__main__":
    analyze_read()
# Out:
# Document contains content:  Contoso
# 123 Main Street Redmond, WA 98052 987-654-3210
# 6/10/2019 13:59 Sales Associate: Paul
# 2 Surface Pro 6 $1,998.00
# 3 Surface Pen $299.97
# Sub-Total
# $2,297.97
# Tax
# $218.31
# Total
# $2,516.28
# ----Analyzing Read from page #1----
# Page has width: 2448.0 and height: 3264.0, measured with unit: pixel
# ...Line # 0 has text content 'Contoso' within bounding box '[863.0, 270.0], [1605.0, 269.0], [1605.0, 412.0], [863.0, 416.0]'
# ...Line # 1 has text content '123 Main Street' within bounding box '[588.0, 705.0], [1179.0, 701.0], [1180.0, 787.0], [588.0, 792.0]'
# ...Line # 2 has text content 'Redmond, WA 98052' within bounding box '[586.0, 838.0], [1371.0, 830.0], [1372.0, 924.0], [586.0, 930.0]'
# ...Line # 3 has text content '987-654-3210' within bounding box '[591.0, 1112.0], [1111.0, 1112.0], [1111.0, 1200.0], [591.0, 1202.0]'
# ...Line # 4 has text content '6/10/2019 13:59' within bounding box '[584.0, 1387.0], [1157.0, 1386.0], [1158.0, 1483.0], [584.0, 1486.0]'
# ...Line # 5 has text content 'Sales Associate: Paul' within bounding box '[584.0, 1523.0], [1417.0, 1523.0], [1417.0, 1611.0], [584.0, 1611.0]'
# ...Line # 6 has text content '2 Surface Pro 6' within bounding box '[604.0, 1799.0], [1236.0, 1795.0], [1236.0, 1887.0], [604.0, 1891.0]'
# ...Line # 7 has text content '$1,998.00' within bounding box '[1526.0, 1796.0], [1879.0, 1796.0], [1879.0, 1893.0], [1526.0, 1892.0]'
# ...Line # 8 has text content '3 Surface Pen' within bounding box '[601.0, 1943.0], [1178.0, 1942.0], [1178.0, 2031.0], [601.0, 2033.0]'
# ...Line # 9 has text content '$299.97' within bounding box '[1591.0, 1935.0], [1885.0, 1936.0], [1887.0, 2029.0], [1589.0, 2033.0]'
# ...Line # 10 has text content 'Sub-Total' within bounding box '[830.0, 2222.0], [1212.0, 2222.0], [1212.0, 2311.0], [830.0, 2312.0]'
# ...Line # 11 has text content '$2,297.97' within bounding box '[1524.0, 2221.0], [1891.0, 2224.0], [1890.0, 2320.0], [1523.0, 2317.0]'
# ...Line # 12 has text content 'Tax' within bounding box '[838.0, 2365.0], [975.0, 2368.0], [975.0, 2447.0], [835.0, 2450.0]'
# ...Line # 13 has text content '$218.31' within bounding box '[1616.0, 2358.0], [1892.0, 2359.0], [1894.0, 2451.0], [1612.0, 2451.0]'
# ...Line # 14 has text content 'Total' within bounding box '[845.0, 2651.0], [1035.0, 2653.0], [1037.0, 2738.0], [843.0, 2740.0]'
# ...Line # 15 has text content '$2,516.28' within bounding box '[1548.0, 2646.0], [1907.0, 2645.0], [1908.0, 2736.0], [1548.0, 2739.0]'
# ...Word 'Contoso' has a confidence of 0.994
# ...Word '123' has a confidence of 0.996
# ...Word 'Main' has a confidence of 0.993
# ...Word 'Street' has a confidence of 0.993
# ...Word 'Redmond,' has a confidence of 0.993
# ...Word 'WA' has a confidence of 0.984
# ...Word '98052' has a confidence of 0.995
# ...Word '987-654-3210' has a confidence of 0.993
# ...Word '6/10/2019' has a confidence of 0.993
# ...Word '13:59' has a confidence of 0.995
# ...Word 'Sales' has a confidence of 0.994
# ...Word 'Associate:' has a confidence of 0.983
# ...Word 'Paul' has a confidence of 0.99
# ...Word '2' has a confidence of 0.995
# ...Word 'Surface' has a confidence of 0.994
# ...Word 'Pro' has a confidence of 0.995
# ...Word '6' has a confidence of 0.995
# ...Word '$1,998.00' has a confidence of 0.989
# ...Word '3' has a confidence of 0.997
# ...Word 'Surface' has a confidence of 0.994
# ...Word 'Pen' has a confidence of 0.995
# ...Word '$299.97' has a confidence of 0.991
# ...Word 'Sub-Total' has a confidence of 0.993
# ...Word '$2,297.97' has a confidence of 0.994
# ...Word 'Tax' has a confidence of 0.996
# ...Word '$218.31' has a confidence of 0.995
# ...Word 'Total' has a confidence of 0.995
# ...Word '$2,516.28' has a confidence of 0.995
# ----------------------------------------

# %% [markdown]
# ## ID 문서 모델

# %%
"""
This code sample shows Prebuilt Read operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://learn.microsoft.com/azure/applied-ai-services/form-recognizer/quickstarts/get-started-v3-sdk-rest-api?view=doc-intel-3.1.0&pivots=programming-language-python
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

# -> pip install azure-ai-formrecognizer
"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
endpoint = "https://b040-document.cognitiveservices.azure.com/"
key = "9njyuOpUp5Z5pFEZmGom6Yt8lMSP4FnVSKeHm981aJnUUCfFC5VPJQQJ99ALAC4f1cMXJ3w3AAALACOGqCyV"

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

def analyze_read():
    # sample document
    #formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"
    formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/rest-api/identity_documents.png"
    
    document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    poller = document_analysis_client.begin_analyze_document_from_url(
            "prebuilt-read", formUrl)
    result = poller.result()

    print ("Document contains content: ", result.content)
    
    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")


if __name__ == "__main__":
    analyze_read()
# Out:
# Document contains content:  WEST VIRGINIA
# Commercial Driver's License
# CHRIS SMITH Main Street , Charleston, WV 456789
# CLASS: A
# RESTR: NONE
# LIC #: 034568
# DOB:
# 03/23/1988
# EXP:
# 03/23/2026
# ISS:
# 03/23/2019
# DD: 12645646464554646456464544
# END: NONE
# SEX:
# M
# HGT: 5'11"
# WGT: 185LB
# EYES: BLU
# ORGAN DONOR
# ----Analyzing Read from page #1----
# Page has width: 759.0 and height: 463.0, measured with unit: pixel
# ...Line # 0 has text content 'WEST VIRGINIA' within bounding box '[105.0, 32.0], [365.0, 32.0], [365.0, 64.0], [105.0, 64.0]'
# ...Line # 1 has text content 'Commercial' within bounding box '[555.0, 18.0], [721.0, 18.0], [721.0, 44.0], [555.0, 45.0]'
# ...Line # 2 has text content 'Driver's License' within bounding box '[530.0, 48.0], [746.0, 48.0], [746.0, 76.0], [530.0, 76.0]'
# ...Line # 3 has text content 'CHRIS SMITH' within bounding box '[255.0, 105.0], [511.0, 105.0], [511.0, 142.0], [255.0, 142.0]'
# ...Line # 4 has text content 'Main Street , Charleston,' within bounding box '[261.0, 152.0], [562.0, 152.0], [561.0, 180.0], [261.0, 179.0]'
# ...Line # 5 has text content 'WV 456789' within bounding box '[260.0, 182.0], [393.0, 182.0], [394.0, 207.0], [260.0, 208.0]'
# ...Line # 6 has text content 'CLASS: A' within bounding box '[258.0, 237.0], [348.0, 237.0], [348.0, 260.0], [258.0, 260.0]'
# ...Line # 7 has text content 'RESTR: NONE' within bounding box '[411.0, 235.0], [554.0, 235.0], [554.0, 260.0], [411.0, 260.0]'
# ...Line # 8 has text content 'LIC #: 034568' within bounding box '[258.0, 267.0], [419.0, 266.0], [420.0, 290.0], [258.0, 291.0]'
# ...Line # 9 has text content 'DOB:' within bounding box '[259.0, 298.0], [311.0, 298.0], [310.0, 322.0], [259.0, 321.0]'
# ...Line # 10 has text content '03/23/1988' within bounding box '[329.0, 297.0], [467.0, 297.0], [467.0, 321.0], [329.0, 321.0]'
# ...Line # 11 has text content 'EXP:' within bounding box '[259.0, 331.0], [299.0, 331.0], [299.0, 351.0], [259.0, 351.0]'
# ...Line # 12 has text content '03/23/2026' within bounding box '[330.0, 326.0], [467.0, 327.0], [467.0, 352.0], [330.0, 351.0]'
# ...Line # 13 has text content 'ISS:' within bounding box '[259.0, 361.0], [291.0, 360.0], [292.0, 383.0], [259.0, 383.0]'
# ...Line # 14 has text content '03/23/2019' within bounding box '[329.0, 356.0], [469.0, 356.0], [469.0, 381.0], [329.0, 382.0]'
# ...Line # 15 has text content 'DD: 12645646464554646456464544' within bounding box '[258.0, 411.0], [531.0, 411.0], [531.0, 431.0], [258.0, 431.0]'
# ...Line # 16 has text content 'END: NONE' within bounding box '[590.0, 237.0], [718.0, 235.0], [719.0, 259.0], [590.0, 260.0]'
# ...Line # 17 has text content 'SEX:' within bounding box '[588.0, 267.0], [632.0, 267.0], [632.0, 290.0], [588.0, 291.0]'
# ...Line # 18 has text content 'M' within bounding box '[647.0, 267.0], [670.0, 267.0], [670.0, 289.0], [648.0, 288.0]'
# ...Line # 19 has text content 'HGT: 5'11"' within bounding box '[586.0, 300.0], [708.0, 298.0], [708.0, 319.0], [586.0, 321.0]'
# ...Line # 20 has text content 'WGT: 185LB' within bounding box '[589.0, 329.0], [720.0, 328.0], [720.0, 351.0], [589.0, 353.0]'
# ...Line # 21 has text content 'EYES: BLU' within bounding box '[588.0, 359.0], [695.0, 358.0], [695.0, 381.0], [589.0, 382.0]'
# ...Line # 22 has text content 'ORGAN DONOR' within bounding box '[558.0, 414.0], [673.0, 414.0], [673.0, 429.0], [558.0, 429.0]'
# ...Word 'WEST' has a confidence of 0.992
# ...Word 'VIRGINIA' has a confidence of 0.994
# ...Word 'Commercial' has a confidence of 0.993
# ...Word 'Driver's' has a confidence of 0.995
# ...Word 'License' has a confidence of 0.995
# ...Word 'CHRIS' has a confidence of 0.995
# ...Word 'SMITH' has a confidence of 0.989
# ...Word 'Main' has a confidence of 0.993
# ...Word 'Street' has a confidence of 0.995
# ...Word ',' has a confidence of 0.988
# ...Word 'Charleston,' has a confidence of 0.992
# ...Word 'WV' has a confidence of 0.995
# ...Word '456789' has a confidence of 0.994
# ...Word 'CLASS:' has a confidence of 0.986
# ...Word 'A' has a confidence of 0.995
# ...Word 'RESTR:' has a confidence of 0.993
# ...Word 'NONE' has a confidence of 0.993
# ...Word 'LIC' has a confidence of 0.995
# ...Word '#:' has a confidence of 0.961
# ...Word '034568' has a confidence of 0.995
# ...Word 'DOB:' has a confidence of 0.991
# ...Word '03/23/1988' has a confidence of 0.993
# ...Word 'EXP:' has a confidence of 0.99
# ...Word '03/23/2026' has a confidence of 0.995
# ...Word 'ISS:' has a confidence of 0.961
# ...Word '03/23/2019' has a confidence of 0.993
# ...Word 'DD:' has a confidence of 0.993
# ...Word '12645646464554646456464544' has a confidence of 0.966
# ...Word 'END:' has a confidence of 0.991
# ...Word 'NONE' has a confidence of 0.988
# ...Word 'SEX:' has a confidence of 0.92
# ...Word 'M' has a confidence of 0.995
# ...Word 'HGT:' has a confidence of 0.988
# ...Word '5'11"' has a confidence of 0.916
# ...Word 'WGT:' has a confidence of 0.99
# ...Word '185LB' has a confidence of 0.995
# ...Word 'EYES:' has a confidence of 0.994
# ...Word 'BLU' has a confidence of 0.997
# ...Word 'ORGAN' has a confidence of 0.995
# ...Word 'DONOR' has a confidence of 0.995
# ----------------------------------------
